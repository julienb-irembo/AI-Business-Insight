# %%
table_service_category ="""
    CREATE TABLE public.table_vone_service_category (
        code varchar(100) PRIMARY KEY,
        name varchar(200)
    );
"""

table_institution ="""
    CREATE TABLE public.table_vone_institution (
        code varchar(100) PRIMARY KEY,
        name varchar(200)
    );
"""

table_application_processing_office ="""
    CREATE TABLE public.table_vone_application_processing_office (
        code varchar(100) PRIMARY KEY,
        name varchar(200)
    );
"""

table_application_processing_location_sector ="""
    CREATE TABLE public.table_vone_application_processing_location_sector (
        code varchar(100) PRIMARY KEY,
        name varchar(200)
    );
"""

table_application_processing_location_district ="""
    CREATE TABLE public.table_vone_application_processing_location_district (
        code varchar(100) PRIMARY KEY,
        name varchar(200)
    );
"""

table_service ="""
    CREATE TABLE public.table_vone_service (
        code varchar(100) PRIMARY KEY,
        name varchar(200),
        category_code varchar(100),
        category_name varchar(200),
        institution_code varchar(100),    
        institution_name varchar(200),        
        FOREIGN KEY (category_code) REFERENCES table_vone_service_category(code),
        FOREIGN KEY (institution_code) REFERENCES table_vone_institution(code)
    );
"""

table_application = """
    CREATE TABLE public.table_vone_application (
        application_number varchar(100) PRIMARY KEY,
        price  int,
        processing_duration int,
        paid_amount int,
        processing_sla  int,
        service_code varchar(100), 
        service_name varchar(200), 
        service_category_code varchar(100), 
        service_category_name varchar(200), 
        institution_code varchar(100),
        institution_name varchar(200),
        application_channel varchar(100),
        application_state varchar(100),
        application_state_details varchar(100),
        application_date_created timestamp,
        application_date_payment timestamp,
        application_currency varchar(100),
        application_processing_phase varchar(100),
        application_requester_location_sector varchar(100),
        application_requester_location_district varchar(100),
        application_requester_id varchar(100),
        application_requester_type varchar(100),
        application_processing_office_code varchar(100),
        application_processing_office_name varchar(200),
        application_processing_location_sector_code varchar(100),
        application_processing_location_sector_name varchar(200),
        application_processing_location_district_code varchar(100),
        application_processing_location_district_name varchar(200),
        application_processing_level varchar(100),
        application_processing_reason varchar(200),
        application_payment_account varchar(100),
        application_payment_state varchar(100),
    
        FOREIGN KEY (service_code) REFERENCES table_vone_service(code),
        FOREIGN KEY (service_category_code) REFERENCES table_vone_service_category(code),
        FOREIGN KEY (institution_code) REFERENCES table_vone_institution(code),
        FOREIGN KEY (application_processing_office_code) REFERENCES table_vone_application_processing_office(code),
        FOREIGN KEY (application_processing_location_sector_code) REFERENCES table_vone_application_processing_location_sector(code),
        FOREIGN KEY (application_processing_location_district_code) REFERENCES table_vone_application_processing_location_district(code)
    );
"""

# %%
# Init Connection
#import sqlite3

import psycopg2

DB_NAME = "postgres"
DB_USER = "postgres.nwecdrxfnogwxbfwauxw"
DB_PASS = "TeamIremboAI"
DB_HOST = "aws-0-eu-central-1.pooler.supabase.com"
DB_PORT = "5432"

conn = psycopg2.connect(database=DB_NAME,
        user=DB_USER,
        password=DB_PASS,
        host=DB_HOST,
        port=DB_PORT)

# %%
# Create Data base Tables
cursor = conn.cursor()
cursor.execute(table_service_category)
cursor.execute(table_institution)
cursor.execute(table_service)
cursor.execute(table_application_processing_office)
cursor.execute(table_application_processing_location_sector)
cursor.execute(table_application_processing_location_district)
cursor.execute(table_application)
conn.commit()

# %%
insert_table_category = """
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_23', 'Rwanda Investigation Bureau');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_13', 'Ingoro Ndangamurage z''u Rwanda');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_36', 'Other');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_37', 'Local Government');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_34', 'Sport and Culture');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_10', 'Uburezi');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_24', 'Trade and Industry');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_06', 'Polisi');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_02', 'Irangamimerere');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_01', 'Family');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_17', 'Ubwikorezi');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_39', 'Meteo service');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_35', 'Explosives Import permit');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_30', 'Local government');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_41', 'Justice');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_15', 'Imitegekere');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_31', 'Configuration track');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_26', 'Import permit');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_05', 'Serivisi za Noteri na serivisi y''igazeti');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_29', 'Veterinary');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_21', 'Disaster Management');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_08', 'Icyemezo cy’Ubushinjacyaha');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_11', 'Itangazamakuru');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_45', 'Diaspora Services');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_12', 'Abinjira n''Abasohoka');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_53', 'Sport');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_33', 'Sports services');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_38', 'Environment and Disaster');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_32', 'NGO services');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_09', 'Ubuzima');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_43', 'Legalization service');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_27', 'Infrastructure');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_40', 'Partnerships and Collaborations');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_03', 'Ubutaka');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_20', 'Viza');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_44', 'Refugee Services');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_46', 'Permits');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_28', 'Agriculture');
INSERT INTO public.table_vone_service_category (code, name) VALUES ('CAT_07', 'Sports and Culture');
"""

cursor = conn.cursor()
cursor.execute(insert_table_category)
conn.commit()

# %%
insert_table_institution = """

INSERT INTO public.table_vone_institution (code, name) VALUES ('METEO', 'Rwanda Meteorology Agency');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINAFFET', 'Minisiteri y''Ububanyi n''Amahanga n''Ubutwererane');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RICA', 'Rwanda Inspectorate, Competition and Consumer Protection Authority');
INSERT INTO public.table_vone_institution (code, name) VALUES ('CNLG', 'National Commission for the Fight Against Genocide');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RTDA', 'Rwanda Transport Development Agency');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RCS', 'Rwanda Correctional Service');
INSERT INTO public.table_vone_institution (code, name) VALUES ('IREMBO', 'Irembo');
INSERT INTO public.table_vone_institution (code, name) VALUES ('HEC', 'Higher Education Council');
INSERT INTO public.table_vone_institution (code, name) VALUES ('NPPA', 'Ubushinjacyaha Bukuru');
INSERT INTO public.table_vone_institution (code, name) VALUES ('REB', 'Rwanda Education Board');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RBC', 'Rwanda Biomedical Center');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINEDUC', 'Ministry of Education');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINAGRI', 'Ministry of Agriculture and Animal Resources');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MININTER', 'Ministry of Interior');
INSERT INTO public.table_vone_institution (code, name) VALUES ('NISR', 'National Institute of Statistics of Rwanda');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RNRA', 'Ikigo cy''Igihugu gishinzwe Imicungire n''Imikoreshereze y''Ubutaka');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RDB', 'Rwanda Development Board');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MFA', 'Ministry of Foreign Affairs');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RCA', 'Ikigo cy''Igihugu cy''Amakoperative');
INSERT INTO public.table_vone_institution (code, name) VALUES ('NESA', 'National Examination and School Inspection Authority');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RMC', 'Rwanda Media Council');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RAB', 'Ikigo cy''Igihugu cy''Ubuhinzi');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RGB', 'Ikigo cy''Igihugu gishinzwe Imiyoborere');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RSSB', 'Ikigo cy''Ubwiteganyirize mu Rwanda');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINISPORTS', 'Ministry of Sports');
INSERT INTO public.table_vone_institution (code, name) VALUES ('NAEB', 'National Agricultural Export Development Board');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RURA', 'PUBLIC');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RDBTOURISM', 'Ikigo cy''Igihugu cy''Iterambere');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RCHA', 'Rwanda Cultural Heritage Academy');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RRA', 'Rwanda Revenue Authority');
INSERT INTO public.table_vone_institution (code, name) VALUES ('PMO', 'Ibiro bya Minisitiri w''Intebe');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINEACOM', 'Minisiteri Y''Ubucuruzi n''Inganda');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_institution (code, name) VALUES ('NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINISPOC', 'Ministry of Sport and Culture');
INSERT INTO public.table_vone_institution (code, name) VALUES ('DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RIB', 'Rwanda Investigation Bureau');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RFA', 'Rwanda Forestry Authority');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RHA', 'Ikigo gishinzwe Imiturire mu Rwanda');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINICOM', 'Ministry of trade and industry');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MIGEPROF', 'Ministry of Gender and Family Promotion');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINIYOUTH', 'Ministry of Youth and Arts');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINUBUMWE', 'Ministry of National Unity & Civic Engagement');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINEMA', 'Ministry in charge of Emergency Management');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MOH', 'Ministry of Health');
INSERT INTO public.table_vone_institution (code, name) VALUES ('RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_institution (code, name) VALUES ('MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');

"""

cursor = conn.cursor()
cursor.execute(insert_table_institution)
conn.commit()

# %%
insert_table_service = """

INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REQUESTING_TO_ADD_OR_REMOVE_LAND_OWNERS', 'Gusaba kongeramo cyangwa gukuramo ba nyirubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RENEW_PERMIT', 'Gusaba indi permit', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_VACCINATION', 'Yellow fever vaccination', 'CAT_09', 'Ubuzima', 'RBC', 'Rwanda Biomedical Center');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_CONVERSION_OF_TENURE_PAYMENT', 'Guhindura uburenganzira k''ubutaka buva k''uwabuhoranye bujya k''ubufite ubu', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHANGE_OF_LAND_USE', 'Guhindura imikoreshereze y''ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_TITLE_UPDATE', 'Gukosoza amakuru y''abantu banditse ku byangombwa by''ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BIRTH_CERTIFICATE', 'Birth Certificate', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_GENOCIDE_SURVIVORS', 'Icyemezo cy''uwacitse ku icumu rya Jenoside yakorewe Abatutsi mu 1994', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('WIDOW_WIDOWER_CERTIFICATE', 'Certificate for Widow/Widower', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BIRTH_CERTIFICATE_EXTRACT', 'Extract of the Birth Certificate', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_OF_LAND_TITLE_VOLUNTARY_SALE', 'Ubugure', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_OF_LAND_TITLE_BY_DONATION', 'Impano', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_OF_LAND_TITLE_BASED_ON_SUCCESSION_INHERITANCE', 'Izungura', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_OF_LAND_TITLE_BY_COURT_ORDER', 'Icyemezo cy''urukiko', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_CERTIFICATE_OF_LAND_OWNERSHIP_PAYMENT', 'Icyangombwa cy''umutungo w''ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHILD_REGISTRATION', 'Child Registration', 'CAT_01', 'Family', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('ADOPTION_EXTRACT_CERTIFICATE', 'Extract of the Adoption certificate', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MARRIAGE_CERTIFICATE_EXTRACT', 'Extract of the Marriage Certificate', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_RECTIFICATION_OF_BOUNDARIES_PAYMENT', 'Gukosora imbibi no gukosora ubuso bw''ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_SUB_DIVISION', 'Kugabanya ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHECK_EXAM_RESULT', 'Amanota y''ikizamini cyo gutwara ibinyabiziga', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_FOR_THE_LOSS_OF_IDENTITY_CARD_TEMPORARY_ID_ISSUANCE', 'Icyemezo gisimbura indangamuntu', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MARRIAGE_RECORD_CERTIFICATE', 'Inyandiko y''Ishyingirwa', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_SUCCESSION', 'Icyemezo cy''izungura', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_NATIONALITY', 'Icyemezo cy''ubwenegihugu', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_COHABITATION', 'Icyemezo cy''imibanire y''abashyingiranwe', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DEATH_CERTIFICATE', 'Icyemezo cy''uko umuntu yitabye Imana', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_RAPID_ISSUANCE_OF_NATIONAL_ID', 'Icyangombwa cyiguhesha indangamuntu mu buryo bwihuse', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_EQUATING_FOREIGN_QUALIFICATIONS_FOR_GENERAL_EDUCATION', 'Icyemezo giha agaciro impamyabumenyi zatangiwe mu mahanga - Icyiciro Rusange', 'CAT_10', 'Uburezi', 'NESA', 'National Examination and School Inspection Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('GUARDIANSHIP_EXTRACT_CERTIFICATE', 'Guardianship Extract Certificate', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHILD_RECOGNITION_EXTRACT_CERTIFICATE', 'Inyandiko Mpine yo kwemera umwana wabyawe n''ababyeyi batashyingiranwe', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BOOKING_AMAHORO_NATIONAL_STADIUM_WITH_THE_GIANT_SCREEN', 'Booking Amahoro National Stadium with the giant screen', 'CAT_07', 'Sports and Culture', 'MINISPOC', 'Ministry of Sport and Culture');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BOOKING_PETIT_STADE_WITH_THE_GIANT_SCREEN', 'Booking Petit stade with the giant screen', 'CAT_07', 'Sports and Culture', 'MINISPOC', 'Ministry of Sport and Culture');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BOOKING_AMAHORO_NATIONAL_STADIUM_WITHOUT_THE_GIANT_SCREEN', 'Booking Amahoro stadium without the giant screen', 'CAT_07', 'Sports and Culture', 'MINISPOC', 'Ministry of Sport and Culture');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BOOKING_PETIT_STADE_WITHOUT_THE_GIANT_SCREEN', 'Booking Petit stade without the giant screen', 'CAT_07', 'Sports and Culture', 'MINISPOC', 'Ministry of Sport and Culture');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BOOKING_STADIUM_PARKING_GARDEN', 'Booking stadium parking/Garden', 'CAT_07', 'Sports and Culture', 'MINISPOC', 'Ministry of Sport and Culture');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_MUTUELLE', 'Kwishyura Mituweli', 'CAT_09', 'Ubuzima', 'RSSB', 'Ikigo cy''Ubwiteganyirize mu Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_OF_CITIZENS_ABOVE_16_YEARS', 'Kwiyandikisha mu gitabo cyandikwamo abaturage', 'CAT_02', 'Irangamimerere', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_TEST_SUPPLEMENTARY', 'Kwiyandikisha gukora ikizamini cyuruhushya rw''icyiciro', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('SUBSCRIBE_FOR_THE_OFFICIAL_GAZETTE', 'Ifatabuguzi ry''Igazeti ya Leta', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MARRIAGE_CERTIFICATE', 'Icyemezo cyo kuba Warashyingiwe', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DEATH_CERTIFICATE_EXTRACT', 'Extract of the Death Certificate', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RWANDAN_LIVING_ABROAD', 'Rwandan Living Abroad', 'CAT_02', 'Irangamimerere', 'MFA', 'Ministry of Foreign Affairs');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('VISIT_RE_SCHEDULE_FOR_NATIONAL_MUSEUMS_OF_RWANDA', 'Guhindura Gahunda yo Gusura', 'CAT_13', 'Ingoro Ndangamurage z''u Rwanda', 'RCHA', 'Institute of National Museums of Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MOTOR_VEHICLE_INSPECTION_DEPOSIT', 'Kubitsa amafaranga y''isuzumisha ry''ibinyabiziga', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DEATH_REGISTRATION', 'Kwandukuza umuntu witabye Imana', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHANGE_OF_NAME_CONFIRMATION', 'Gusaba icyemezo cyo guhindura amazina', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHANGE_OF_NAME_APPLICATION', 'Gusaba uburenganzira bwo guhindura amazina', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('ADOPTION_RECORD_CERTIFICATE', 'Inyandiko yo kubera umubyeyi umwana utabyaye', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DEATH_RECORD_CERTIFICATE', 'Death Record', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('GUARDIANSHIP_RECORD_CERTIFICATE', 'Inyandiko y''ubwishingire', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_FULL_IDENTITY', 'Icyemezo cy''umwirondoro wuzuye', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_FOR_BEING_SINGLE', 'Icyemezo cy''uko uri ingaragu', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MARRIAGE_REGISTRATION', 'Kwiyandikisha ngo ushyingirwe', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOREIGNER_IDENTIFICATION_CARD', 'Gusaba indangamuntu y''umunyamahanga', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_PERMIT', 'Gusaba permit', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_TRANSPORT_AUTHORIZATION', 'Gusaba uruhushya rwo gutwara abantu', 'CAT_17', 'Ubwikorezi', 'RURA', 'PUBLIC');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSPORT_AUTHORIZATION_RENEWAL', 'kongererwa igihe cy''uruhushya rwo gutwara abantu', 'CAT_17', 'Ubwikorezi', 'RURA', 'PUBLIC');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('SPORADIC_REGISTRATION', 'Kwandikisha ubutaka butabaruwe', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('ACCREDITATION_FOR_FOREIGN_MEDIA', 'Accreditation for Foreign Media', 'CAT_11', 'Itangazamakuru', 'RMC', 'Rwanda Media Council');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RENEW_VISA', 'Gusaba indi viza', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REPLACE_LAISSEZ_PASSER', 'Guhinduza laissez-passer', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RENEW_LAISSEZ_PASSER', 'Gusaba laissez-passer yindi', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CITIZENSHIP_REGISTRATION', 'Kwinyandikisha usaba ubwenegihugu', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('AUTHENTICATION_OF_LOAN_AGREEMENT', 'Gutiza Ingwate', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_REPLACEMENT_OF_LAND_DOCUMENT', 'Gusimbura ibyangombwa by''ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_BEING_ALIVE', 'Icyemezo cy''uko umuntu ariho', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_RESIDENCE', 'Icyemezo cy''uko utuye', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_MERGING', 'Guhuza ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_LAISSEZ_PASSER', 'Gusaba laissez-passer', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('NOTARY_SERVICE', 'Serivisi yo Gushyirisha Umukono wa Noteri ku Nyandiko', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REPLACE_FOREIGNER_IDENTIFICATION_CARD', 'Guhinduza indangamuntu y''umunyamahanga', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_COVID_19_TEST_USD', 'COVID-19 Test - USD', 'CAT_09', 'Ubuzima', 'RBC', 'Rwanda Biomedical Center');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_COVID_19_TEST_RWF', 'COVID-19 Test - RWF', 'CAT_09', 'Ubuzima', 'RBC', 'Rwanda Biomedical Center');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_TRANSPORT_LICENSE', 'Gusaba Uburenganzira bwo gutwara abantu', 'CAT_17', 'Ubwikorezi', 'RURA', 'PUBLIC');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DGIE_PENALTIES_PAYMENT', 'Kwishyura Ibihano', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSPORT_LICENSE_RENEWAL', 'kongererwa igihe cy''uburenganzira bwo gutwara abantu', 'CAT_17', 'Ubwikorezi', 'RURA', 'PUBLIC');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_CONDOMINIUM_REGISTRATION_PAYMENT', 'Kwandikisha uburenganzira ku butaka buhuriweho n''abantu benshi', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_CONVERSION_FROM_LEASE_TO_FREE_HOLD_PAYMENT', 'Guhindura ubukode bw''ubutaka bukaba inkondabutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_FICHE_CADASTRALE_PAYMENT', 'Ifishi y''ubutaka', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('VISA_ON_ARRIVAL', 'Viza Uhabwa Ugeze mu Gihugu', 'CAT_20', 'Viza', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_TRANSCRIPTION_FEES', 'Kwishyurira Kwimura Dosiye', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_NEW_DOCUMENT_PAYMENT', 'Icyangombwa cy''ubutaka gishya', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_VISA', 'Gusaba viza', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CEPGL_TRAVEL_DOCUMENT_NEW', 'Gusaba Urwandiko rw''inzira rwa CEPGL', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_PASSPORT', 'e-Passport first application', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LOST_DAMAGE_PASSPORT', 'e-Passport replacement', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('EPASSPORT_DIASPORA', 'Kwishyura DPA', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CEPGL_TRAVEL_DOCUMENT_RENEWAL', 'Gusaba urundi rwandiko rw''inzira rwa CEPGL', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DEATH_RECORD_NEW', 'Inyandiko yuko umuntu yitabye Imana (Nshya)', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('PURCHASE_FOR_AN_OFFICIAL_GAZETTE', 'Kugura Igazeti ya Leta', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DIVORCE_RECORD', 'Divorce Record', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TVET_FOREIGN_EQUIVALENCE_CERTIFICATE', 'Icyemezo giha agaciro impamyabushobozi za TVET', 'CAT_10', 'Uburezi', 'NESA', 'National Examination and School Inspection Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CITIZENSHIP_APPLICATION_PAYMENTS', 'CITIZENSHIP_APPLICATION_PAYMENTS_NAME', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('BIRTH_RECORD_NEW', 'Inyandiko y''Ivuka', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MARRIAGE_DECLARATION', 'Kwandikisha Ishyingirwa', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CEPGL_TRAVEL_DOCUMENT', 'CEPGL Travel Document', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MARRIAGE_RECORD_NEW', 'Inyandiko y''Ishyingirwa (Nshya)', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_TEST_DEFINITIVE', 'Kwiyandikisha gukora ikizamini cy''uruhushya rwa burundu', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CERTIFICATE_OF_DIVORCE', 'Certificate of Divorce', 'CAT_02', 'Irangamimerere', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CEPGL_TRAVEL_DOCUMENT_REPLACE', 'Gusimbuza urwandiko rw''inzira rwa CEPGL', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RDB_NOTARY_SERVICE', 'RDB Notary service', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CITIZENSHIP_RENUNCIATION_PAYMENT', 'CITIZENSHIP_RENUNCIATION_PAYMENTS_SERVICE_NAME', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_PROVISIONAL_DRIVING_LICENSE', 'Guhabwa uruhushya rw''agateganyo watsindiye', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRAFFIC_FINES', 'Kwishyura konterevasiyo', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_TEST_PROVISIONAL', 'Kwiyandikisha gukora ikizamini cy''uruhushya rw''agateganyo', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DUPLICATE_OF_MOTOR_VEHICLE_INSPECTION_CERTIFICATE', 'Kopi y''icyemezo cy''isuzuma ry''ikinyabiziga', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MOTOR_VEHICLE_INSPECTION_APPOINTMENT', 'Gusaba umunsi wo kujya gukoresha kontorole', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_PERMIT_AND_VISA_TRANSFER', 'Permit or Visa Transfer', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_OF_LAND_TITLE_BASED_ON_EXCHANGE', 'Igurana', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_LICENSE_TEST_SUPPLEMENTARY', 'Kwiyandikisha gukora ikizamini cy''uruhushya rw''icyiciro kisumbuye.', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('NID_DIASPORA_WITHOUT_NPR_REVAMP', 'Gusaba indangamuntu ku banyarwanda baba mu mahanga badafite umubare wa NPR', 'CAT_02', 'Irangamimerere', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_LICENSE_TEST_DEFINITIVE', 'Kwiyandikisha gukora ikizamini cy''uruhushya rwa burundu rwo gutwara ikinyabiziga', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHILD_RECOGNITION_RECORD_CERTIFICATE', 'Record of recognition.', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CHILD_RECOGNITION_RECORD_NEW', 'Record of recognition new', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('CRIMINAL_RECORD_CLEARANCE_CERTIFICATE', 'Icyangombwa cyerekana ko umuntu yakatiwe cyangwa atakatiwe n''inkiko', 'CAT_08', 'Icyemezo cy’Ubushinjacyaha', 'NPPA', 'Ubushinjacyaha Bukuru');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_E_PROVISIONAL_DRIVING_LICENSE', 'Guhabwa Uruhushya rw''Agateganyo Nkoranabuhanga', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('ADOPTION_RECORD_NEW', 'Adoption Record', 'CAT_01', 'Family', 'MINALOC', 'Minisiteri y''Ubutegetsi bw''Igihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('TRANSFER_OF_LAND_E_TITLE_VOLUNTARY_SALE', 'Voluntary sale with e-title', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_LICENSE_TEST_PROVISIONAL_PAPER_BASED', 'Registration for Driving Test - Provisional, paper-based', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REGISTRATION_FOR_DRIVING_LICENSE_TEST_PROVISIONAL_COMPUTER_BASED', 'Registration for Driving Test - Provisional, computer-based', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('FOREIGNER_TRAVEL_DOCUMENT', 'Urwandiko rw''Inzira Rwatangiwe mu Mahanga', 'CAT_12', 'Abinjira n''Abasohoka', 'DGIE', 'Ubuyobozi Bukuru bw''Abinjira n''Abasohoka mu Gihugu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RGB_NOTARY_SERVICE', 'RGB Notary service', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('SECTOR_NOTARY_SERVICE', 'Sector Notary service', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DISTRICT_NOTARY_SERVICE', 'District Notary service', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('MINIJUST_NOTARY_SERVICE', 'Minijust Notary service', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('LAND_FIRST_REGISTRATION_PAYMENT', 'Iyandikisha ry''ubutaka butabaruwe', 'CAT_03', 'Ubutaka', 'RLMUA', 'National Land Authority');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_DEFINITIVE_DRIVING_LICENCE', 'Guhabwa uruhushya rwa burundu watsindiye', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REPLACEMENT_OF_NATIONAL_ID', 'Gusimbuza Indangamuntu Yatakaye', 'CAT_02', 'Irangamimerere', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('REPLACEMENT_OF_DRIVING_LICENSE', 'Gusimbuza/Guhinduza uruhushya rwa burundu', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DUPLICATE_OF_DEFINITIVE_DRIVING_LICENSE', 'Gusaba kopi y''uruhushya rwa burundu', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_FBO_LEGAL_PERSONALITY', 'Kwandikisha no Guhabwa Ubuzima Gatozi ku Miryango ishingiye ku Myemerere', 'CAT_15', 'Imitegekere', 'RGB', 'Ikigo cy''Igihugu gishinzwe Imiyoborere');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DRIVING_LICENSE_CATEGORY_UPGRADE', 'Guhabwa uruhushya rw''icyiciro kisumbuye watsindiye', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('DUPLICATE_OF_PROVISIONAL_DRIVING_LICENSE', 'Gusaba kopi y''uruhushya rw''agateganyo', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('NGO_REGISTRATION', 'Kwandikisha Umuryango utari uwa Leta', 'CAT_15', 'Imitegekere', 'RGB', 'Ikigo cy''Igihugu gishinzwe Imiyoborere');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RENEWAL_OF_PROVISIONAL_DRIVING_LICENSE', 'Kongera igihe cy''uruhushya rw''agateganyo', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('RENEWAL_OF_DEFINITIVE_DRIVING_LICENSE', 'Kongera igihe cy''uruhushya rwa burundu', 'CAT_06', 'Polisi', 'RNP', 'Polisi y''u Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('VISIT_SCHEDULE_FOR_NATIONAL_MUSEUMS_OF_RWANDA', 'Gufata Gahunda yo Gusura', 'CAT_13', 'Ingoro Ndangamurage z''u Rwanda', 'RCHA', 'Institute of National Museums of Rwanda');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('PUBLISH_IN_THE_OFFICIAL_GAZETTE', 'Kwamamaza mw''Igazeti ya Leta', 'CAT_05', 'Serivisi za Noteri na serivisi y''igazeti', 'MINIJUST', 'Ministry of Justice');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_NATIONAL_ID', 'Application for National ID', 'CAT_02', 'Irangamimerere', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_EQUATING_FOREIGN_QUALIFICATIONS_PHD_MASTERS_DEGREES_DIPLOMAS_AND_CERTIFICATES', 'Foreign Qualifications Validation', 'CAT_10', 'Uburezi', 'HEC', 'Higher Education Council');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('APPLICATION_FOR_NGO_LEGAL_PERSONALITY', 'Gusaba Ubuzima Gatozi bw''Umuryango utari uwa Leta', 'CAT_15', 'Imitegekere', 'RGB', 'Ikigo cy''Igihugu gishinzwe Imiyoborere');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('NID_DIASPORA_WITHOUT_NPR', 'Gusaba indangamuntu ku banyarwanda baba mu mahanga badafite umubare wa NPR OLD', 'CAT_02', 'Irangamimerere', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('PAYMENT_FOR_ID_CORRECTION', 'Gusaba gukosorerwa Indangamuntu', 'CAT_02', 'Irangamimerere', 'NIDA', 'Ikigo cy''Igihugu gishinzwe Indangamuntu');
INSERT INTO public.table_vone_service(code, name, category_code, category_name, institution_code, institution_name) VALUES ('NEW_CRIMINAL_RECORD_CLEARANCE_CERTIFICATE', 'Icyangombwa cyerekana ko umuntu yakatiwe cyangwa atakatiwe n''inkiko.', 'CAT_08', 'Icyemezo cy’Ubushinjacyaha', 'NPPA', 'Ubushinjacyaha Bukuru');


"""

cursor = conn.cursor()
cursor.execute(insert_table_service)
conn.commit()

# %%
# insert_table_application_processing_office
insert_table_application_processing_office = """

INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Abouja', 'Ambarwa Abouja');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Abu Dabi', 'Ambarwa Abu Dabi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Accra', 'Ambarwa Accra');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Addis Abeba', 'Ambarwa Addis Abeba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Amsterdam', 'Ambarwa Amsterdam');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Ankara', 'Ambarwa Ankara');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Beijing', 'Ambarwa Beijing');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Berlin', 'Ambarwa Berlin');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Brazzaville', 'Ambarwa Brazzaville');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Brusselle', 'Ambarwa Brusselle');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Bujumbura', 'Ambarwa Bujumbura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Cairo', 'Ambarwa Cairo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Dakar', 'Ambarwa Dakar');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Dar es Salam', 'Ambarwa Dar es Salam');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Delhi', 'Ambarwa Delhi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Doha', 'Ambarwa Doha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Geneve', 'Ambarwa Geneve');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Harare', 'Ambarwa Harare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Kampala', 'Ambarwa Kampala');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Khartoum', 'Ambarwa Khartoum');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Kinshasa', 'Ambarwa Kinshasa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Londres', 'Ambarwa Londres');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Luanda', 'Ambarwa Luanda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Lusaka', 'Ambarwa Lusaka');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Maputo', 'Ambarwa Maputo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Moscou', 'Ambarwa Moscou');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Nairobi', 'Ambarwa Nairobi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Ottawa', 'Ambarwa Ottawa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Paris', 'Ambarwa Paris');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Pretoria', 'Ambarwa Pretoria');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Rabat', 'Ambarwa Rabat');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Seoul', 'Ambarwa Seoul');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Singapore', 'Ambarwa Singapore');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Stockholm', 'Ambarwa Stockholm');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Tel Aviv', 'Ambarwa Tel Aviv');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Tokyo', 'Ambarwa Tokyo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Warsaw', 'Ambarwa Warsaw');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ambarwa Washington', 'Ambarwa Washington');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Base', 'Base');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bigogwe', 'Bigogwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Boneza', 'Boneza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bugarama', 'Bugarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bugesera', 'Bugesera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bugeshi', 'Bugeshi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bukure', 'Bukure');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bumbogo', 'Bumbogo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bungwe', 'Bungwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Burega', 'Burega');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Burera', 'Burera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Buruhukiro', 'Buruhukiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Busanze', 'Busanze');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Busasamana', 'Busasamana');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Busengo', 'Busengo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bushekeri', 'Bushekeri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bushenge', 'Bushenge');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bushoki', 'Bushoki');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Busogo', 'Busogo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Busoro', 'Busoro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Butare', 'Butare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Butaro', 'Butaro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Buyoga', 'Buyoga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bweramana', 'Bweramana');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bweyeye', 'Bweyeye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bwira', 'Bwira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bwishyura', 'Bwishyura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Bwisige', 'Bwisige');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Byimana', 'Byimana');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Byumba', 'Byumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('CNLG HQ in Kigali', 'CNLG HQ in Kigali');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('CYAGA NDIMUBANZI Eric', 'CYAGA NDIMUBANZI Eric');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Coko', 'Coko');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Concile de Melbourne', 'Concile de Melbourne');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyabakamyi', 'Cyabakamyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyabingo', 'Cyabingo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyahinda', 'Cyahinda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyanika', 'Cyanika');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyanzarwe', 'Cyanzarwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyato', 'Cyato');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyeru', 'Cyeru');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyeza', 'Cyeza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyinzuzi', 'Cyinzuzi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyumba', 'Cyumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyungo', 'Cyungo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Cyuve', 'Cyuve');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('DGIE', 'DGIE');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('DGIE HQ in Kigali', 'DGIE HQ in Kigali');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Fumbwe', 'Fumbwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gacaca', 'Gacaca');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gacurabwenge', 'Gacurabwenge');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gahanga', 'Gahanga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gahara', 'Gahara');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gahengeri', 'Gahengeri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gahini', 'Gahini');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gahunga', 'Gahunga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gakenke', 'Gakenke');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gasabo', 'Gasabo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gasaka', 'Gasaka');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gasange', 'Gasange');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gashaki', 'Gashaki');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gashanda', 'Gashanda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gashari', 'Gashari');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gashenyi', 'Gashenyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gashonga', 'Gashonga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gashora', 'Gashora');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gataraga', 'Gataraga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatare', 'Gatare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatebe', 'Gatebe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatenga', 'Gatenga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatore', 'Gatore');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatsata', 'Gatsata');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatsibo', 'Gatsibo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatumba', 'Gatumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gatunda', 'Gatunda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gicumbi', 'Gicumbi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gihango', 'Gihango');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Giheke', 'Giheke');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gihombo', 'Gihombo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gihundwe', 'Gihundwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gikomero', 'Gikomero');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gikondo', 'Gikondo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gikonko', 'Gikonko');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gikundamvura', 'Gikundamvura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gisagara', 'Gisagara');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gisenyi', 'Gisenyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gishali', 'Gishali');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gishamvu', 'Gishamvu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gishubi', 'Gishubi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gishyita', 'Gishyita');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gisozi', 'Gisozi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gitambi', 'Gitambi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gitega', 'Gitega');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gitesi', 'Gitesi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Giti', 'Giti');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gitoki', 'Gitoki');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Gitovu', 'Gitovu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('HEC', 'HEC');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Hindiro', 'Hindiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Hotel', 'Hotel');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Huye', 'Huye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('INMR Headquarters', 'INMR Headquarters');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Jabana', 'Jabana');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Jali', 'Jali');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Janja', 'Janja');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Jarama', 'Jarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Jenda', 'Jenda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Jomba', 'Jomba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Juru', 'Juru');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('KAYUMBA Gracien', 'KAYUMBA Gracien');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('KCEV - Camp Kigali (KN 3 Ave, Kigali)', 'KCEV - Camp Kigali (KN 3 Ave, Kigali)');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabacuzi', 'Kabacuzi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabagali', 'Kabagali');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabare', 'Kabare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabarondo', 'Kabarondo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabarore', 'Kabarore');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabatwa', 'Kabatwa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kabaya', 'Kabaya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kacyiru', 'Kacyiru');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kaduha', 'Kaduha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kagano', 'Kagano');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kagarama', 'Kagarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kageyo', 'Kageyo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kagogo', 'Kagogo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kamabuye', 'Kamabuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kamegeri', 'Kamegeri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kamembe', 'Kamembe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kamonyi', 'Kamonyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kamubuga', 'Kamubuga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kanama', 'Kanama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kaniga', 'Kaniga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kanjongo', 'Kanjongo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kanombe', 'Kanombe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kansi', 'Kansi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kanyinya', 'Kanyinya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kanzenze', 'Kanzenze');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karago', 'Karago');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karama', 'Karama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karambi', 'Karambi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karambo', 'Karambo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karangazi', 'Karangazi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karembo', 'Karembo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karenge', 'Karenge');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karengera', 'Karengera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Karongi', 'Karongi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Katabagemu', 'Katabagemu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kavumu', 'Kavumu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kayenzi', 'Kayenzi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kayonza', 'Kayonza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kayumbu', 'Kayumbu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kazo', 'Kazo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kibangu', 'Kibangu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kibeho', 'Kibeho');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kibilizi', 'Kibilizi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kibirizi', 'Kibirizi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kibumbwe', 'Kibumbwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kibungo', 'Kibungo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kicukiro', 'Kicukiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigabiro', 'Kigabiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigali', 'Kigali');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigarama', 'Kigarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigembe', 'Kigembe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigeyo', 'Kigeyo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigina', 'Kigina');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kigoma', 'Kigoma');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kimihurura', 'Kimihurura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kimironko', 'Kimironko');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kimisagara', 'Kimisagara');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kimonyi', 'Kimonyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kinazi', 'Kinazi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kinigi', 'Kinigi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kinihira', 'Kinihira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kinoni', 'Kinoni');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kintobo', 'Kintobo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kinyababa', 'Kinyababa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kinyinya', 'Kinyinya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kiramuruzi', 'Kiramuruzi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kirehe', 'Kirehe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kirimbi', 'Kirimbi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kisaro', 'Kisaro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kitabi', 'Kitabi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kivu', 'Kivu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kivumu', 'Kivumu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kivuruga', 'Kivuruga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kivuye', 'Kivuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kiyombe', 'Kiyombe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kiyumba', 'Kiyumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Kiziguro', 'Kiziguro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MHC', 'MHC');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MINALOC', 'MINALOC');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MINICOM Office', 'MINICOM Office');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MINIJUST', 'MINIJUST');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MINIYOUTH PS office', 'MINIYOUTH PS office');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MUDAGIRI Alexis', 'MUDAGIRI Alexis');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('MUGABO Leandre Martin', 'MUGABO Leandre Martin');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Macuba', 'Macuba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mageragere', 'Mageragere');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mahama', 'Mahama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mahembe', 'Mahembe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mamba', 'Mamba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Manihira', 'Manihira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Manyagiro', 'Manyagiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Maraba', 'Maraba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mareba', 'Mareba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Masaka', 'Masaka');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Masoro', 'Masoro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mata', 'Mata');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mataba', 'Mataba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Matimba', 'Matimba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Matyazo', 'Matyazo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mayange', 'Mayange');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mbazi', 'Mbazi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mbogo', 'Mbogo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mbuye', 'Mbuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mimuri', 'Mimuri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Minazi', 'Minazi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Miyove', 'Miyove');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mpanga', 'Mpanga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mubuga', 'Mubuga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mudende', 'Mudende');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mugano', 'Mugano');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muganza', 'Muganza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mugesera', 'Mugesera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mugina', 'Mugina');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mugombwa', 'Mugombwa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mugunga', 'Mugunga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhanda', 'Muhanda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhanga', 'Muhanga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhazi', 'Muhazi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhima', 'Muhima');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhondo', 'Muhondo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhororo', 'Muhororo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhoza', 'Muhoza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muhura', 'Muhura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mukama', 'Mukama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mukamira', 'Mukamira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mukarange', 'Mukarange');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mukindo', 'Mukindo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mukingo', 'Mukingo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muko', 'Muko');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mukura', 'Mukura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Munini', 'Munini');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Munyaga', 'Munyaga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Munyiginya', 'Munyiginya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Murama', 'Murama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Murambi', 'Murambi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muringa', 'Muringa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Murunda', 'Murunda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Murundi', 'Murundi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mururu', 'Mururu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musambira', 'Musambira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musange', 'Musange');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musanze', 'Musanze');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musasa', 'Musasa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musaza', 'Musaza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musebeya', 'Musebeya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musenyi', 'Musenyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musha', 'Musha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Musheri', 'Musheri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mushikiri', 'Mushikiri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mushishiro', 'Mushishiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mushonyi', 'Mushonyi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mushubati', 'Mushubati');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mushubi', 'Mushubi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mutenderi', 'Mutenderi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mutete', 'Mutete');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mutuntu', 'Mutuntu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muyira', 'Muyira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muyongwe', 'Muyongwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muyumbu', 'Muyumbu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Muzo', 'Muzo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mwendo', 'Mwendo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mwiri', 'Mwiri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mwogo', 'Mwogo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Mwulire', 'Mwulire');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('NESA Headquarter', 'NESA Headquarter');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('NIDA', 'NIDA');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('NPPA Headquarters Kimihurura', 'NPPA Headquarters Kimihurura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nagatare', 'Nagatare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nasho', 'Nasho');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ndaro', 'Ndaro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ndego', 'Ndego');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ndera', 'Ndera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ndora', 'Ndora');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nduba', 'Nduba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nemba', 'Nemba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ngamba', 'Ngamba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ngarama', 'Ngarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ngera', 'Ngera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ngeruka', 'Ngeruka');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ngoma', 'Ngoma');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ngororero', 'Ngororero');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Niboye', 'Niboye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nkanka', 'Nkanka');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nkomane', 'Nkomane');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nkombo', 'Nkombo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nkotsi', 'Nkotsi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nkungu', 'Nkungu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ntarabana', 'Ntarabana');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ntarama', 'Ntarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ntongwe', 'Ntongwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ntyazo', 'Ntyazo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyabihu', 'Nyabihu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyabimata', 'Nyabimata');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyabinoni', 'Nyabinoni');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyabirasi', 'Nyabirasi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyabitekeri', 'Nyabitekeri');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyagatare', 'Nyagatare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyagihanga', 'Nyagihanga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyagisozi', 'Nyagisozi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyakabanda', 'Nyakabanda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyakabuye', 'Nyakabuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyakaliro', 'Nyakaliro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyakarenzo', 'Nyakarenzo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyakiriba', 'Nyakiriba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamabuye', 'Nyamabuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamagabe', 'Nyamagabe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamasheke', 'Nyamasheke');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamata', 'Nyamata');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamirama', 'Nyamirama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamirambo', 'Nyamirambo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamiyaga', 'Nyamiyaga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamugari', 'Nyamugari');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyamyumba', 'Nyamyumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyange', 'Nyange');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyankenke', 'Nyankenke');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyanza', 'Nyanza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyarubaka', 'Nyarubaka');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyarubuye', 'Nyarubuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyarugenge', 'Nyarugenge');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyarugunga', 'Nyarugunga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyaruguru', 'Nyaruguru');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyarusange', 'Nyarusange');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nyundo', 'Nyundo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nzahaha', 'Nzahaha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Nzige', 'Nzige');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RBC', 'RBC');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RBC Gikondo Offices', 'RBC Gikondo Offices');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RCHA DG office', 'RCHA DG office');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RCHA officer office', 'RCHA officer office');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RDB', 'RDB');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RGB', 'RGB');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RICA Office', 'RICA Office');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RNP Headquarters', 'RNP Headquarters');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RSSB', 'RSSB');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RUKOZO', 'RUKOZO');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('RURA', 'RURA');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rambura', 'Rambura');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rangiro', 'Rangiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Remera', 'Remera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ririma', 'Ririma');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rongi', 'Rongi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rubavu', 'Rubavu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rubaya', 'Rubaya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rubengera', 'Rubengera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rubona', 'Rubona');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugabano', 'Rugabano');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruganda', 'Ruganda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugarama', 'Rugarama');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugarika', 'Rugarika');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugendabari', 'Rugendabari');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugengabari', 'Rugengabari');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugera', 'Rugera');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rugerero', 'Rugerero');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruhango', 'Ruhango');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruharambuga', 'Ruharambuga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruhashya', 'Ruhashya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruheru', 'Ruheru');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruhuha', 'Ruhuha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruhunde', 'Ruhunde');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rukara', 'Rukara');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rukira', 'Rukira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rukoma', 'Rukoma');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rukomo', 'Rukomo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rukumberi', 'Rukumberi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruli', 'Ruli');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rulindo', 'Rulindo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Runda', 'Runda');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruramba', 'Ruramba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruramira', 'Ruramira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rurembo', 'Rurembo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rurenge', 'Rurenge');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusarabuye', 'Rusarabuye');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusasa', 'Rusasa');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusatira', 'Rusatira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusebeya', 'Rusebeya');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusenge', 'Rusenge');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rushaki', 'Rushaki');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rushashi', 'Rushashi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusiga', 'Rusiga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusizi', 'Rusizi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rusororo', 'Rusororo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rutare', 'Rutare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rutsiro', 'Rutsiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rutunga', 'Rutunga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Ruvune', 'Ruvune');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwabicuma', 'Rwabicuma');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwamagana', 'Rwamagana');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwamiko', 'Rwamiko');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwaniro', 'Rwaniro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwankuba', 'Rwankuba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwaza', 'Rwaza');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwempasha', 'Rwempasha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwerere', 'Rwerere');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rweru', 'Rweru');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwezamenyo', 'Rwezamenyo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwimbogo', 'Rwimbogo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwimiyaga', 'Rwimiyaga');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Rwinkwavu', 'Rwinkwavu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('SPORT Office', 'SPORT Office');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Sake', 'Sake');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Save', 'Save');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shangasha', 'Shangasha');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shangi', 'Shangi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shingiro', 'Shingiro');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shyara', 'Shyara');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shyira', 'Shyira');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shyogwe', 'Shyogwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Shyorongo', 'Shyorongo');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Simbi', 'Simbi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Sovu', 'Sovu');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Tabagwe', 'Tabagwe');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Tare', 'Tare');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Tumba', 'Tumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Twumba', 'Twumba');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Uwinkingi', 'Uwinkingi');
INSERT INTO public.table_vone_application_processing_office(code, name) VALUES ('Zaza', 'Zaza');

""" 

cursor = conn.cursor()
cursor.execute(insert_table_application_processing_office)
conn.commit()

# %%
# insert_table_application_processing_location_sector
insert_table_application_processing_location_sector = """ 
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010101', 'Gitega');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010102', 'Kanyinya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010103', 'Kigali');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010104', 'Kimisagara');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010105', 'Mageragere');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010106', 'Muhima');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010107', 'Nyakabanda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010108', 'Nyamirambo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010109', 'Nyarugenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010110', 'Rwezamenyo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010201', 'Bumbogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010202', 'Gatsata');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010203', 'Gikomero');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010204', 'Gisozi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010205', 'Jabana');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010206', 'Jali');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010207', 'Kacyiru');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010208', 'Kimihurura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010209', 'Kimironko');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010210', 'Kinyinya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010211', 'Ndera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010212', 'Nduba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010213', 'Remera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010214', 'Rusororo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010215', 'Rutunga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010301', 'Gahanga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010302', 'Gatenga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010303', 'Gikondo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010304', 'Kagarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010305', 'Kanombe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010306', 'Kicukiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010307', 'Kigarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010308', 'Masaka');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010309', 'Niboye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('010310', 'Nyarugunga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020101', 'Busasamana');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020102', 'Busoro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020103', 'Cyabakamyi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020104', 'Kibilizi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020105', 'Kigoma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020106', 'Mukingo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020107', 'Muyira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020108', 'Ntyazo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020109', 'Nyagisozi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020110', 'Rwabicuma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020201', 'Gikonko');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020202', 'Gishubi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020203', 'Kansi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020204', 'Kibirizi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020205', 'Kigembe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020206', 'Mamba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020207', 'Muganza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020208', 'Mugombwa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020209', 'Mukindo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020210', 'Musha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020211', 'Ndora');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020212', 'Nyanza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020213', 'Save');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020301', 'Busanze');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020302', 'Cyahinda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020303', 'Kibeho');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020304', 'Kivu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020305', 'Mata');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020306', 'Muganza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020307', 'Munini');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020308', 'Ngera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020309', 'Ngoma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020310', 'Nyabimata');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020311', 'Nyagisozi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020312', 'Ruheru');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020313', 'Ruramba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020314', 'Rusenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020401', 'Gishamvu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020402', 'Huye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020403', 'Karama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020404', 'Kigoma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020405', 'Kinazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020406', 'Maraba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020407', 'Mbazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020408', 'Mukura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020409', 'Ngoma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020410', 'Ruhashya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020411', 'Rusatira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020412', 'Rwaniro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020413', 'Simbi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020414', 'Tumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020501', 'Buruhukiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020502', 'Cyanika');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020503', 'Gasaka');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020504', 'Gatare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020505', 'Kaduha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020506', 'Kamegeri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020507', 'Kibirizi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020508', 'Kibumbwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020509', 'Kitabi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020510', 'Mbazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020511', 'Mugano');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020512', 'Musange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020513', 'Musebeya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020514', 'Mushubi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020515', 'Nkomane');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020516', 'Tare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020517', 'Uwinkingi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020601', 'Bweramana');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020602', 'Byimana');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020603', 'Kabagali');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020604', 'Kinazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020605', 'Kinihira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020606', 'Mbuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020607', 'Mwendo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020608', 'Ntongwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020609', 'Ruhango');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020701', 'Cyeza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020702', 'Kabacuzi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020703', 'Kibangu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020704', 'Kiyumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020705', 'Muhanga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020706', 'Mushishiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020707', 'Nyabinoni');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020708', 'Nyamabuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020709', 'Nyarusange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020710', 'Rongi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020711', 'Rugendabari');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020712', 'Shyogwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020801', 'Gacurabwenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020802', 'Karama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020803', 'Kayenzi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020804', 'Kayumbu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020805', 'Mugina');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020806', 'Musambira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020807', 'Ngamba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020808', 'Nyamiyaga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020809', 'Nyarubaka');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020810', 'Rugarika');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020811', 'Rukoma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('020812', 'Runda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030101', 'Bwishyura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030102', 'Gashari');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030103', 'Gishyita');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030104', 'Gitesi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030105', 'Mubuga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030106', 'Murambi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030107', 'Murundi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030108', 'Mutuntu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030109', 'Rubengera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030110', 'Rugabano');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030111', 'Ruganda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030112', 'Rwankuba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030113', 'Twumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030201', 'Boneza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030202', 'Gihango');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030203', 'Kigeyo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030204', 'Kivumu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030205', 'Manihira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030206', 'Mukura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030207', 'Murunda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030208', 'Musasa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030209', 'Mushonyi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030210', 'Mushubati');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030211', 'Nyabirasi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030212', 'Ruhango');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030213', 'Rusebeya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030301', 'Bugeshi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030302', 'Busasamana');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030303', 'Cyanzarwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030304', 'Gisenyi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030305', 'Kanama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030306', 'Kanzenze');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030307', 'Mudende');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030308', 'Nyakiriba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030309', 'Nyamyumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030310', 'Nyundo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030311', 'Rubavu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030312', 'Rugerero');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030401', 'Bigogwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030402', 'Jenda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030403', 'Jomba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030404', 'Kabatwa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030405', 'Karago');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030406', 'Kintobo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030407', 'Mukamira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030408', 'Muringa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030409', 'Rambura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030410', 'Rugera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030411', 'Rurembo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030412', 'Shyira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030601', 'Bugarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030602', 'Butare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030603', 'Bweyeye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030604', 'Gashonga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030605', 'Giheke');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030606', 'Gihundwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030607', 'Gikundamvura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030608', 'Gitambi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030609', 'Kamembe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030610', 'Muganza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030611', 'Mururu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030612', 'Nkanka');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030613', 'Nkombo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030614', 'Nkungu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030615', 'Nyakabuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030616', 'Nyakarenzo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030617', 'Nzahaha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030618', 'Rwimbogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030701', 'Bushekeri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030702', 'Bushenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030703', 'Cyato');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030704', 'Gihombo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030705', 'Kagano');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030706', 'Kanjongo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030707', 'Karambi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030708', 'Karengera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030709', 'Kirimbi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030710', 'Macuba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030711', 'Mahembe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030712', 'Nyabitekeri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030713', 'Rangiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030714', 'Ruharambuga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030715', 'Shangi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040201', 'Busengo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040202', 'Coko');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040203', 'Cyabingo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040204', 'Gakenke');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040205', 'Gashenyi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040206', 'Janja');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040207', 'Kamubuga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040208', 'Karambo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040209', 'Kivuruga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040210', 'Mataba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040211', 'Minazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040212', 'Mugunga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040213', 'Muhondo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040214', 'Muyongwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040215', 'Muzo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040216', 'Nemba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040217', 'Ruli');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040218', 'Rusasa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040219', 'Rushashi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040301', 'Busogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040302', 'Cyuve');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040303', 'Gacaca');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040304', 'Gashaki');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040305', 'Gataraga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040306', 'Kimonyi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040307', 'Kinigi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040308', 'Muhoza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040309', 'Muko');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040310', 'Musanze');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040311', 'Nkotsi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040312', 'Nyange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040313', 'Remera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040314', 'Rwaza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040315', 'Shingiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040401', 'Bungwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040402', 'Butaro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040403', 'Cyanika');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040404', 'Cyeru');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040405', 'Gahunga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040406', 'Gatebe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040407', 'Gitovu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040408', 'Kagogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040409', 'Kinoni');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040410', 'Kinyababa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040411', 'Kivuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040412', 'Nemba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040413', 'Rugarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040414', 'Rugengabari');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040415', 'Ruhunde');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040416', 'Rusarabuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040417', 'Rwerere');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040501', 'Bukure');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040502', 'Bwisige');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040503', 'Byumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040504', 'Cyumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040505', 'Giti');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040506', 'Kageyo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040507', 'Kaniga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040508', 'Manyagiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040509', 'Miyove');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040510', 'Mukarange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040511', 'Muko');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040512', 'Mutete');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040513', 'Nyamiyaga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040514', 'Nyankenke');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040515', 'Rubaya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040516', 'Rukomo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040517', 'Rushaki');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040518', 'Rutare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040519', 'Ruvune');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040520', 'Rwamiko');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040521', 'Shangasha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050101', 'Fumbwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050102', 'Gahengeri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050103', 'Gishali');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050104', 'Karenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050105', 'Kigabiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050106', 'Muhazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050107', 'Munyaga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050108', 'Munyiginya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050109', 'Musha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050110', 'Muyumbu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050111', 'Mwulire');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050112', 'Nyakaliro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050113', 'Nzige');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050114', 'Rubona');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050301', 'Gasange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050302', 'Gatsibo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050303', 'Gitoki');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050304', 'Kabarore');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050305', 'Kageyo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050306', 'Kiramuruzi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050307', 'Kiziguro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050308', 'Muhura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050309', 'Murambi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050310', 'Ngarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050311', 'Nyagihanga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050312', 'Remera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050313', 'Rugarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050314', 'Rwimbogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050401', 'Gahini');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050402', 'Kabare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050403', 'Kabarondo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050404', 'Mukarange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050405', 'Murama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050406', 'Murundi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050407', 'Mwiri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050408', 'Ndego');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050409', 'Nyamirama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050410', 'Rukara');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050411', 'Ruramira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050412', 'Rwinkwavu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050501', 'Gahara');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050502', 'Gatore');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050503', 'Kigarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050504', 'Kigina');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050505', 'Kirehe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050506', 'Mahama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050507', 'Mpanga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050508', 'Musaza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050509', 'Mushikiri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050510', 'Nasho');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050511', 'Nyamugari');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050512', 'Nyarubuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050601', 'Gashanda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050602', 'Jarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050603', 'Karembo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050604', 'Kazo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050605', 'Kibungo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050606', 'Mugesera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050607', 'Murama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050608', 'Mutenderi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050609', 'Remera');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050610', 'Rukira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050611', 'Rukumberi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050612', 'Rurenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050613', 'Sake');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050614', 'Zaza');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050701', 'Gashora');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050702', 'Juru');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050703', 'Kamabuye');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050704', 'Mareba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050705', 'Mayange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050706', 'Musenyi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050707', 'Mwogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050708', 'Ngeruka');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050709', 'Ntarama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050710', 'Nyamata');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050711', 'Nyarugenge');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050712', 'Ririma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050713', 'Ruhuha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050714', 'Rweru');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050715', 'Shyara');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040111', 'Murambi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050201', 'Gatunda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050208', 'Mukama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050210', 'Nyagatare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040107', 'Kinihira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030503', 'Hindiro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030506', 'Kavumu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050202', 'Karama');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050203', 'Karangazi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030512', 'Nyange');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040117', 'Tumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030502', 'Gatumba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030509', 'Muhororo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040110', 'Mbogo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050207', 'Mimuri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030511', 'Ngororero');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040108', 'Kisaro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050213', 'Rwimiyaga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040105', 'Cyinzuzi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030501', 'Bwira');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050206', 'Matimba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040115', 'Rusiga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050211', 'Rukomo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030505', 'Kageyo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040113', 'Ntarabana');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030504', 'Kabaya');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040102', 'Burega');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040103', 'Bushoki');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040106', 'Cyungo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030510', 'Ndaro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050204', 'Katabagemu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050205', 'Kiyombe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050212', 'Rwempasha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030513', 'Sovu');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030507', 'Matyazo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050214', 'Tabagwe');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('030508', 'Muhanda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040114', 'Rukozo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040109', 'Masoro');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040101', 'Base');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('050209', 'Musheri');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040104', 'Buyoga');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040112', 'Ngoma');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('040116', 'Shyorongo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060101', 'Ambarwa Pretoria');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060201', 'Ambarwa Berlin');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060202', 'Ambarwa Londres');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060501', 'Concile de Melbourne');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060301', 'Ambarwa Ottawa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060302', 'Ambarwa Washington');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060401', 'Ambarwa Beijing');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060402', 'Ambarwa Seoul');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060403', 'Ambarwa Delhi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060404', 'Ambarwa Tokyo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060102', 'Ambarwa Bujumbura');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060103', 'Ambarwa Addis Abeba');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060104', 'Ambarwa Nairobi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060105', 'Ambarwa Kampala');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060106', 'Ambarwa Khartoum');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060107', 'Ambarwa Dar es Salam');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060108', 'Ambarwa Kinshasa');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060109', 'Ambarwa Dakar');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060110', 'Ambarwa Abouja');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060112', 'Ambarwa Brazzaville');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060115', 'Ambarwa Accra');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060111', 'Ambarwa Lusaka');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060113', 'Ambarwa Luanda');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060114', 'Ambarwa Cairo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060116', 'Ambarwa Rabat');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060117', 'Ambarwa Maputo');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060118', 'Ambarwa Harare');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060203', 'Ambarwa Amsterdam');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060204', 'Ambarwa Stockholm');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060205', 'Ambarwa Geneve');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060206', 'Ambarwa Brusselle');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060207', 'Ambarwa Paris');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060405', 'Ambarwa Ankara');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060406', 'Ambarwa Moscou');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060407', 'Ambarwa Tel Aviv');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060408', 'Ambarwa Abu Dabi');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060409', 'Ambarwa Doha');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060410', 'Ambarwa Singapore');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060209', 'Ambarwa Warsaw');
INSERT INTO public.table_vone_application_processing_location_sector (code, name) VALUES ('060208', 'Ambarwa Geneva');

"""


cursor = conn.cursor()
cursor.execute(insert_table_application_processing_location_sector)
conn.commit()

# %%
# insert_table_application_processing_location_district

insert_table_application_processing_location_district = """ 
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0101', 'Nyarugenge');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0102', 'Gasabo');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0103', 'Kicukiro');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0201', 'Nyanza');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0202', 'Gisagara');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0203', 'Nyaruguru');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0204', 'Huye');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0205', 'Nyamagabe');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0206', 'Ruhango');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0207', 'Muhanga');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0208', 'Kamonyi');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0301', 'Karongi');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0302', 'Rutsiro');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0303', 'Rubavu');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0304', 'Nyabihu');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0305', 'Ngororero');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0306', 'Rusizi');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0307', 'Nyamasheke');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0401', 'Rulindo');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0402', 'Gakenke');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0403', 'Musanze');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0404', 'Burera');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0405', 'Gicumbi');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0501', 'Rwamagana');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0502', 'Nyagatare');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0503', 'Gatsibo');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0504', 'Kayonza');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0505', 'Kirehe');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0506', 'Ngoma');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0507', 'Bugesera');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0601', 'Africa');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0602', 'Europe');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0603', 'America');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0604', 'Asia');
INSERT INTO public.table_vone_application_processing_location_district (code, name) VALUES ('0605', 'Australia');

"""
cursor = conn.cursor()
cursor.execute(insert_table_application_processing_location_district)
conn.commit()

# %%
# office_list
office_list = [
    ['Gitega','10101',''],
    ['Kanyinya','10102',''],
    ['Kigali','10103',''],
    ['DGIE HQ in Kigali','10103',''],
    ['Kimisagara','10104',''],
    ['Mageragere','10105',''],
    ['Muhima','10106',''],
    ['Nyakabanda','10107',''],
    ['Nyamirambo','10108',''],
    ['Nyarugenge','10109',''],
    ['Rwezamenyo','10110',''],
    ['Bumbogo','10201',''],
    ['Gatsata','10202',''],
    ['Gikomero','10203',''],
    ['Gisozi','10204',''],
    ['Jabana','10205',''],
    ['Jali','10206',''],
    ['Kacyiru','10207',''],
    ['CYAGA NDIMUBANZI Eric','10207',''],
    ['MINICOM Office','10207',''],
    ['Kimihurura','10208',''],
    ['Kimironko','10209',''],
    ['Kinyinya','10210',''],
    ['Ndera','10211',''],
    ['Nduba','10212',''],
    ['Remera','10213',''],
    ['Rusororo','10214',''],
    ['Rutunga','10215',''],
    ['Gahanga','10301',''],
    ['Gatenga','10302',''],
    ['Gikondo','10303',''],
    ['Kagarama','10304',''],
    ['Kanombe','10305',''],
    ['Kicukiro','10306',''],
    ['Kigarama','10307',''],
    ['Masaka','10308',''],
    ['Niboye','10309',''],
    ['Nyarugunga','10310',''],
    ['Busasamana','20101',''],
    ['Busoro','20102',''],
    ['Cyabakamyi','20103',''],
    ['Kibilizi','20104',''],
    ['Kigoma','20105',''],
    ['Mukingo','20106',''],
    ['Muyira','20107',''],
    ['Ntyazo','20108',''],
    ['Nyagisozi','20109',''],
    ['Rwabicuma','20110',''],
    ['Gikonko','20201',''],
    ['Gishubi','20202',''],
    ['Kansi','20203',''],
    ['Kibirizi','20204',''],
    ['Kigembe','20205',''],
    ['Mamba','20206',''],
    ['Muganza','20207',''],
    ['Mugombwa','20208',''],
    ['Mukindo','20209',''],
    ['Musha','20210',''],
    ['Ndora','20211',''],
    ['Nyanza','20212',''],
    ['Save','20213',''],
    ['Busanze','20301',''],
    ['Cyahinda','20302',''],
    ['Kibeho','20303',''],
    ['Kivu','20304',''],
    ['Mata','20305',''],
    ['Muganza','20306',''],
    ['Munini','20307',''],
    ['Ngera','20308',''],
    ['Ngoma','20309',''],
    ['Nyabimata','20310',''],
    ['Nyagisozi','20311',''],
    ['Ruheru','20312',''],
    ['Ruramba','20313',''],
    ['Rusenge','20314',''],
    ['Gishamvu','20401',''],
    ['Huye','20402',''],
    ['Karama','20403',''],
    ['Kigoma','20404',''],
    ['Kinazi','20405',''],
    ['Maraba','20406',''],
    ['Mbazi','20407',''],
    ['Mukura','20408',''],
    ['Ngoma','20409',''],
    ['Ruhashya','20410',''],
    ['Rusatira','20411',''],
    ['Rwaniro','20412',''],
    ['Simbi','20413',''],
    ['Tumba','20414',''],
    ['Buruhukiro','20501',''],
    ['Cyanika','20502',''],
    ['Gasaka','20503',''],
    ['Gatare','20504',''],
    ['Kaduha','20505',''],
    ['Kamegeri','20506',''],
    ['Kibirizi','20507',''],
    ['Kibumbwe','20508',''],
    ['Kitabi','20509',''],
    ['Mbazi','20510',''],
    ['Mugano','20511',''],
    ['Musange','20512',''],
    ['Musebeya','20513',''],
    ['Mushubi','20514',''],
    ['Nkomane','20515',''],
    ['Tare','20516',''],
    ['Uwinkingi','20517',''],
    ['Bweramana','20601',''],
    ['Byimana','20602',''],
    ['Kabagali','20603',''],
    ['Kinazi','20604',''],
    ['Kinihira','20605',''],
    ['Mbuye','20606',''],
    ['Mwendo','20607',''],
    ['Ntongwe','20608',''],
    ['Ruhango','20609',''],
    ['Cyeza','20701',''],
    ['Kabacuzi','20702',''],
    ['Kibangu','20703',''],
    ['Kiyumba','20704',''],
    ['Muhanga','20705',''],
    ['Mushishiro','20706',''],
    ['Nyabinoni','20707',''],
    ['Nyamabuye','20708',''],
    ['MUGABO Leandre Martin','20708',''],
    ['Nyarusange','20709',''],
    ['Rongi','20710',''],
    ['Rugendabari','20711',''],
    ['Shyogwe','20712',''],
    ['Gacurabwenge','20801',''],
    ['Karama','20802',''],
    ['Kayenzi','20803',''],
    ['Kayumbu','20804',''],
    ['Mugina','20805',''],
    ['Musambira','20806',''],
    ['Ngamba','20807',''],
    ['Nyamiyaga','20808',''],
    ['Nyarubaka','20809',''],
    ['Rugarika','20810',''],
    ['Rukoma','20811',''],
    ['Runda','20812',''],
    ['Bwishyura','30101',''],
    ['Gashari','30102',''],
    ['Gishyita','30103',''],
    ['Gitesi','30104',''],
    ['Mubuga','30105',''],
    ['Murambi','30106',''],
    ['Murundi','30107',''],
    ['Mutuntu','30108',''],
    ['Rubengera','30109',''],
    ['Rugabano','30110',''],
    ['Ruganda','30111',''],
    ['Rwankuba','30112',''],
    ['Twumba','30113',''],
    ['Boneza','30201',''],
    ['Gihango','30202',''],
    ['Kigeyo','30203',''],
    ['Kivumu','30204',''],
    ['Manihira','30205',''],
    ['Mukura','30206',''],
    ['Murunda','30207',''],
    ['Musasa','30208',''],
    ['Mushonyi','30209',''],
    ['Mushubati','30210',''],
    ['Nyabirasi','30211',''],
    ['Ruhango','30212',''],
    ['Rusebeya','30213',''],
    ['Bugeshi','30301',''],
    ['Busasamana','30302',''],
    ['Cyanzarwe','30303',''],
    ['Gisenyi','30304',''],
    ['Kanama','30305',''],
    ['Kanzenze','30306',''],
    ['Mudende','30307',''],
    ['Nyakiriba','30308',''],
    ['Nyamyumba','30309',''],
    ['Nyundo','30310',''],
    ['Rubavu','30311',''],
    ['Rugerero','30312',''],
    ['Bigogwe','30401',''],
    ['Jenda','30402',''],
    ['Jomba','30403',''],
    ['Kabatwa','30404',''],
    ['Karago','30405',''],
    ['Kintobo','30406',''],
    ['Mukamira','30407',''],
    ['Muringa','30408',''],
    ['Rambura','30409',''],
    ['Rugera','30410',''],
    ['Rurembo','30411',''],
    ['Shyira','30412',''],
    ['Bwira','30501',''],
    ['Gatumba','30502',''],
    ['Hindiro','30503',''],
    ['Kabaya','30504',''],
    ['Kageyo','30505',''],
    ['Kavumu','30506',''],
    ['Matyazo','30507',''],
    ['Muhanda','30508',''],
    ['Muhororo','30509',''],
    ['Ndaro','30510',''],
    ['Ngororero','30511',''],
    ['Nyange','30512',''],
    ['Sovu','30513',''],
    ['Bugarama','30601',''],
    ['Butare','30602',''],
    ['Bweyeye','30603',''],
    ['Gashonga','30604',''],
    ['Giheke','30605',''],
    ['Gihundwe','30606',''],
    ['Gikundamvura','30607',''],
    ['Gitambi','30608',''],
    ['Kamembe','30609',''],
    ['Muganza','30610',''],
    ['Mururu','30611',''],
    ['Nkanka','30612',''],
    ['Nkombo','30613',''],
    ['Nkungu','30614',''],
    ['Nyakabuye','30615',''],
    ['Nyakarenzo','30616',''],
    ['Nzahaha','30617',''],
    ['Rwimbogo','30618',''],
    ['Bushekeri','30701',''],
    ['Bushenge','30702',''],
    ['Cyato','30703',''],
    ['Gihombo','30704',''],
    ['Kagano','30705',''],
    ['Kanjongo','30706',''],
    ['Karambi','30707',''],
    ['Karengera','30708',''],
    ['Kirimbi','30709',''],
    ['Macuba','30710',''],
    ['Mahembe','30711',''],
    ['Nyabitekeri','30712',''],
    ['Rangiro','30713',''],
    ['Ruharambuga','30714',''],
    ['Shangi','30715',''],
    ['Base','40101',''],
    ['Burega','40102',''],
    ['Bushoki','40103',''],
    ['Buyoga','40104',''],
    ['Cyinzuzi','40105',''],
    ['Cyungo','40106',''],
    ['Kinihira','40107',''],
    ['Kisaro','40108',''],
    ['Masoro','40109',''],
    ['Mbogo','40110',''],
    ['Murambi','40111',''],
    ['Ngoma','40112',''],
    ['Ntarabana','40113',''],
    ['RUKOZO','40114',''],
    ['Rusiga','40115',''],
    ['Shyorongo','40116',''],
    ['Tumba','40117',''],
    ['Busengo','40201',''],
    ['Coko','40202',''],
    ['Cyabingo','40203',''],
    ['Gakenke','40204',''],
    ['Gashenyi','40205',''],
    ['Janja','40206',''],
    ['Kamubuga','40207',''],
    ['Karambo','40208',''],
    ['Kivuruga','40209',''],
    ['Mataba','40210',''],
    ['Minazi','40211',''],
    ['Mugunga','40212',''],
    ['Muhondo','40213',''],
    ['Muyongwe','40214',''],
    ['Muzo','40215',''],
    ['Nemba','40216',''],
    ['Ruli','40217',''],
    ['Rusasa','40218',''],
    ['Rushashi','40219',''],
    ['Busogo','40301',''],
    ['Cyuve','40302',''],
    ['Gacaca','40303',''],
    ['Gashaki','40304',''],
    ['Gataraga','40305',''],
    ['Kimonyi','40306',''],
    ['Kinigi','40307',''],
    ['Muhoza','40308',''],
    ['Muko','40309',''],
    ['Musanze','40310',''],
    ['Nkotsi','40311',''],
    ['Nyange','40312',''],
    ['Remera','40313',''],
    ['Rwaza','40314',''],
    ['Shingiro','40315',''],
    ['Bungwe','40401',''],
    ['Butaro','40402',''],
    ['Cyanika','40403',''],
    ['Cyeru','40404',''],
    ['Gahunga','40405',''],
    ['Gatebe','40406',''],
    ['Gitovu','40407',''],
    ['Kagogo','40408',''],
    ['Kinoni','40409',''],
    ['Kinyababa','40410',''],
    ['Kivuye','40411',''],
    ['Nemba','40412',''],
    ['Rugarama','40413',''],
    ['Rugengabari','40414',''],
    ['Ruhunde','40415',''],
    ['Rusarabuye','40416',''],
    ['Rwerere','40417',''],
    ['Bukure','40501',''],
    ['Bwisige','40502',''],
    ['Byumba','40503',''],
    ['Cyumba','40504',''],
    ['Giti','40505',''],
    ['Kageyo','40506',''],
    ['Kaniga','40507',''],
    ['Manyagiro','40508',''],
    ['Miyove','40509',''],
    ['Mukarange','40510',''],
    ['Muko','40511',''],
    ['Mutete','40512',''],
    ['Nyamiyaga','40513',''],
    ['Nyankenke','40514',''],
    ['Rubaya','40515',''],
    ['Rukomo','40516',''],
    ['Rushaki','40517',''],
    ['Rutare','40518',''],
    ['Ruvune','40519',''],
    ['Rwamiko','40520',''],
    ['Shangasha','40521',''],
    ['RSSB','40521',''],
    ['Fumbwe','50101',''],
    ['Gahengeri','50102',''],
    ['Gishali','50103',''],
    ['Karenge','50104',''],
    ['Kigabiro','50105',''],
    ['Muhazi','50106',''],
    ['Munyaga','50107',''],
    ['Munyiginya','50108',''],
    ['Musha','50109',''],
    ['Muyumbu','50110',''],
    ['Mwulire','50111',''],
    ['Nyakaliro','50112',''],
    ['Nzige','50113',''],
    ['Rubona','50114',''],
    ['Gatunda','50201',''],
    ['Karama','50202',''],
    ['Karangazi','50203',''],
    ['Katabagemu','50204',''],
    ['Kiyombe','50205',''],
    ['Matimba','50206',''],
    ['Mimuri','50207',''],
    ['Mukama','50208',''],
    ['Musheri','50209',''],
    ['Nagatare','50210',''],
    ['Rukomo','50211',''],
    ['Rwempasha','50212',''],
    ['Rwimiyaga','50213',''],
    ['Tabagwe','50214',''],
    ['Gasange','50301',''],
    ['Gatsibo','50302',''],
    ['Gitoki','50303',''],
    ['Kabarore','50304',''],
    ['KAYUMBA Gracien','50304',''],
    ['Kageyo','50305',''],
    ['Kiramuruzi','50306',''],
    ['Kiziguro','50307',''],
    ['Muhura','50308',''],
    ['Murambi','50309',''],
    ['Ngarama','50310',''],
    ['Nyagihanga','50311',''],
    ['Remera','50312',''],
    ['Rugarama','50313',''],
    ['Rwimbogo','50314',''],
    ['Gahini','50401',''],
    ['Kabare','50402',''],
    ['Kabarondo','50403',''],
    ['Mukarange','50404',''],
    ['Murama','50405',''],
    ['Murundi','50406',''],
    ['Mwiri','50407',''],
    ['Ndego','50408',''],
    ['Nyamirama','50409',''],
    ['Rukara','50410',''],
    ['Ruramira','50411',''],
    ['Rwinkwavu','50412',''],
    ['Gahara','50501',''],
    ['Gatore','50502',''],
    ['Kigarama','50503',''],
    ['Kigina','50504',''],
    ['Kirehe','50505',''],
    ['Mahama','50506',''],
    ['Mpanga','50507',''],
    ['Musaza','50508',''],
    ['Mushikiri','50509',''],
    ['Nasho','50510',''],
    ['Nyamugari','50511',''],
    ['Nyarubuye','50512',''],
    ['Gashanda','50601',''],
    ['Jarama','50602',''],
    ['Karembo','50603',''],
    ['Kazo','50604',''],
    ['Kibungo','50605',''],
    ['Mugesera','50606',''],
    ['Murama','50607',''],
    ['Mutenderi','50608',''],
    ['Remera','50609',''],
    ['Rukira','50610',''],
    ['Rukumberi','50611',''],
    ['Rurenge','50612',''],
    ['Sake','50613',''],
    ['Zaza','50614',''],
    ['Gashora','50701',''],
    ['Juru','50702',''],
    ['Kamabuye','50703',''],
    ['Mareba','50704',''],
    ['Mayange','50705',''],
    ['Musenyi','50706',''],
    ['Mwogo','50707',''],
    ['Ngeruka','50708',''],
    ['Ntarama','50709',''],
    ['Nyamata','50710',''],
    ['MUDAGIRI Alexis','50710',''],
    ['Nyarugenge','50711',''],
    ['Ririma','50712',''],
    ['Ruhuha','50713',''],
    ['Rweru','50714',''],
    ['Shyara','50715',''],
    ['Ambarwa Pretoria','60101',''],
    ['Ambarwa Bujumbura','60102',''],
    ['Ambarwa Addis Abeba','60103',''],
    ['Ambarwa Nairobi','60104',''],
    ['Ambarwa Kampala','60105',''],
    ['Ambarwa Khartoum','60106',''],
    ['Ambarwa Dar es Salam','60107',''],
    ['Ambarwa Kinshasa','60108',''],
    ['Ambarwa Dakar','60109',''],
    ['Ambarwa Abouja','60110',''],
    ['Ambarwa Lusaka','60111',''],
    ['Ambarwa Brazzaville','60112',''],
    ['Ambarwa Luanda','60113',''],
    ['Ambarwa Cairo','60114',''],
    ['Ambarwa Accra','60115',''],
    ['Ambarwa Rabat','60116',''],
    ['Ambarwa Maputo','60117',''],
    ['Ambarwa Harare','60118',''],
    ['Ambarwa Berlin','60201',''],
    ['Ambarwa Londres','60202',''],
    ['Ambarwa Amsterdam','60203',''],
    ['Ambarwa Stockholm','60204',''],
    ['Ambarwa Geneve','60205',''],
    ['Ambarwa Brusselle','60206',''],
    ['Ambarwa Paris','60207',''],
    ['Ambarwa Warsaw','60209',''],
    ['Ambarwa Ottawa','60301',''],
    ['Ambarwa Washington','60302',''],
    ['Ambarwa Beijing','60401',''],
    ['Ambarwa Seoul','60402',''],
    ['Ambarwa Delhi','60403',''],
    ['Ambarwa Tokyo','60404',''],
    ['Ambarwa Ankara','60405',''],
    ['Ambarwa Moscou','60406',''],
    ['Ambarwa Tel Aviv','60407',''],
    ['Ambarwa Abu Dabi','60408',''],
    ['Ambarwa Doha','60409',''],
    ['Ambarwa Singapore','60410',''],
    ['Concile de Melbourne','60501','']   

]

# %%
# Generate Application data
import string
import random
from datetime import datetime, timedelta

service_list = [
    ['REQUESTING_TO_ADD_OR_REMOVE_LAND_OWNERS','CAT_03','RLMUA','5000','RWF'],
    ['RENEW_PERMIT','CAT_12','DGIE','0','RWF'],
    ['APPLICATION_FOR_VACCINATION','CAT_09','RBC','1500','RWF'],
    ['LAND_CONVERSION_OF_TENURE_PAYMENT','CAT_03','RLMUA','5000','RWF'],
    ['CHANGE_OF_LAND_USE','CAT_03','RLMUA','5000','RWF'],
    ['LAND_TITLE_UPDATE','CAT_03','RLMUA','5000','RWF'],
    ['BIRTH_CERTIFICATE','CAT_01','MINALOC','500','RWF'],
    ['CERTIFICATE_OF_GENOCIDE_SURVIVORS','CAT_01','MINALOC','0','RWF'],
    ['WIDOW_WIDOWER_CERTIFICATE','CAT_01','MINALOC','1500','RWF'],
    ['BIRTH_CERTIFICATE_EXTRACT','CAT_01','MINALOC','1000','RWF'],
    ['TRANSFER_OF_LAND_TITLE_VOLUNTARY_SALE','CAT_03','RLMUA','0','RWF'],
    ['TRANSFER_OF_LAND_TITLE_BY_DONATION','CAT_03','RLMUA','30000','RWF'],
    ['TRANSFER_OF_LAND_TITLE_BASED_ON_SUCCESSION_INHERITANCE','CAT_03','RLMUA','25000','RWF'],
    ['TRANSFER_OF_LAND_TITLE_BY_COURT_ORDER','CAT_03','RLMUA','2500','RWF'],
    ['LAND_CERTIFICATE_OF_LAND_OWNERSHIP_PAYMENT','CAT_03','RLMUA','1500','RWF'],
    ['CHILD_REGISTRATION','CAT_01','NIDA','0','RWF'],
    ['ADOPTION_EXTRACT_CERTIFICATE','CAT_01','MINALOC','1000','RWF'],
    ['MARRIAGE_CERTIFICATE_EXTRACT','CAT_01','MINALOC','1000','RWF'],
    ['LAND_RECTIFICATION_OF_BOUNDARIES_PAYMENT','CAT_03','RLMUA','15000','RWF'],
    ['LAND_SUB_DIVISION','CAT_03','RLMUA','10000','RWF'],
    ['CHECK_EXAM_RESULT','CAT_06','RNP','0','RWF'],
    ['CERTIFICATE_FOR_THE_LOSS_OF_IDENTITY_CARD_TEMPORARY_ID_ISSUANCE','CAT_02','MINALOC','500','RWF'],
    ['MARRIAGE_RECORD_CERTIFICATE','CAT_01','MINALOC','2000','RWF'],
    ['CERTIFICATE_OF_SUCCESSION','CAT_01','MINALOC','0','RWF'],
    ['CERTIFICATE_OF_NATIONALITY','CAT_02','MINALOC','1500','RWF'],
    ['CERTIFICATE_OF_COHABITATION','CAT_01','MINALOC','1500','RWF'],
    ['DEATH_CERTIFICATE','CAT_01','MINALOC','1200','RWF'],
    ['CERTIFICATE_OF_RAPID_ISSUANCE_OF_NATIONAL_ID','CAT_02','MINALOC','0','RWF'],
    ['APPLICATION_FOR_EQUATING_FOREIGN_QUALIFICATIONS_FOR_GENERAL_EDUCATION','CAT_10','NESA','1000','RWF'],
    ['GUARDIANSHIP_EXTRACT_CERTIFICATE','CAT_01','MINALOC','1000','RWF'],
    ['CHILD_RECOGNITION_EXTRACT_CERTIFICATE','CAT_01','MINALOC','1000','RWF'],
    ['BOOKING_AMAHORO_NATIONAL_STADIUM_WITH_THE_GIANT_SCREEN','CAT_07','MINISPOC','3500000','RWF'],
    ['BOOKING_PETIT_STADE_WITH_THE_GIANT_SCREEN','CAT_07','MINISPOC','1500000','RWF'],
    ['BOOKING_AMAHORO_NATIONAL_STADIUM_WITHOUT_THE_GIANT_SCREEN','CAT_07','MINISPOC','3000000','RWF'],
    ['BOOKING_PETIT_STADE_WITHOUT_THE_GIANT_SCREEN','CAT_07','MINISPOC','1000000','RWF'],
    ['BOOKING_STADIUM_PARKING_GARDEN','CAT_07','MINISPOC','500000','RWF'],
    ['APPLICATION_FOR_MUTUELLE','CAT_09','RSSB','0','RWF'],
    ['REGISTRATION_OF_CITIZENS_ABOVE_16_YEARS','CAT_02','NIDA','0','RWF'],
    ['REGISTRATION_FOR_DRIVING_TEST_SUPPLEMENTARY','CAT_06','RNP','10000','RWF'],
    ['SUBSCRIBE_FOR_THE_OFFICIAL_GAZETTE','CAT_05','MINIJUST','0','RWF'],
    ['MARRIAGE_CERTIFICATE','CAT_01','MINALOC','500','RWF'],
    ['DEATH_CERTIFICATE_EXTRACT','CAT_01','MINALOC','1000','RWF'],
    ['RWANDAN_LIVING_ABROAD','CAT_02','MFA','0','RWF'],
    ['VISIT_RE_SCHEDULE_FOR_NATIONAL_MUSEUMS_OF_RWANDA','CAT_13','RCHA','0','RWF'],
    ['MOTOR_VEHICLE_INSPECTION_DEPOSIT','CAT_06','RNP','0','RWF'],
    ['DEATH_REGISTRATION','CAT_01','MINALOC','0','RWF'],
    ['CHANGE_OF_NAME_CONFIRMATION','CAT_02','MINALOC','20000','RWF'],
    ['CHANGE_OF_NAME_APPLICATION','CAT_02','MINALOC','0','RWF'],
    ['ADOPTION_RECORD_CERTIFICATE','CAT_01','MINALOC','2000','RWF'],
    ['DEATH_RECORD_CERTIFICATE','CAT_01','MINALOC','4000','RWF'],
    ['GUARDIANSHIP_RECORD_CERTIFICATE','CAT_01','MINALOC','2000','RWF'],
    ['CERTIFICATE_OF_FULL_IDENTITY','CAT_02','MINALOC','500','RWF'],
    ['CERTIFICATE_FOR_BEING_SINGLE','CAT_01','MINALOC','500','RWF'],
    ['MARRIAGE_REGISTRATION','CAT_01','MINALOC','0','RWF'],
    ['APPLICATION_FOREIGNER_IDENTIFICATION_CARD','CAT_12','DGIE','5000','RWF'],
    ['APPLICATION_PERMIT','CAT_12','DGIE','0','RWF'],
    ['APPLICATION_FOR_TRANSPORT_AUTHORIZATION','CAT_17','RURA','10000','RWF'],
    ['TRANSPORT_AUTHORIZATION_RENEWAL','CAT_17','RURA','10000','RWF'],
    ['SPORADIC_REGISTRATION','CAT_03','RLMUA','5000','RWF'],
    ['ACCREDITATION_FOR_FOREIGN_MEDIA','CAT_11','RMC','0','USD'],
    ['RENEW_VISA','CAT_12','DGIE','0','USD'],
    ['REPLACE_LAISSEZ_PASSER','CAT_12','DGIE','0','RWF'],
    ['RENEW_LAISSEZ_PASSER','CAT_12','DGIE','0','RWF'],
    ['CITIZENSHIP_REGISTRATION','CAT_12','DGIE','0','RWF'],
    ['AUTHENTICATION_OF_LOAN_AGREEMENT','CAT_03','RLMUA','5000','RWF'],
    ['APPLICATION_FOR_REPLACEMENT_OF_LAND_DOCUMENT','CAT_03','RLMUA','5000','RWF'],
    ['CERTIFICATE_OF_BEING_ALIVE','CAT_02','MINALOC','1200','RWF'],
    ['CERTIFICATE_OF_RESIDENCE','CAT_01','MINALOC','1500','RWF'],
    ['LAND_MERGING','CAT_03','RLMUA','5000','RWF'],
    ['APPLICATION_LAISSEZ_PASSER','CAT_12','DGIE','0','RWF'],
    ['NOTARY_SERVICE','CAT_05','MINIJUST','0','RWF'],
    ['REPLACE_FOREIGNER_IDENTIFICATION_CARD','CAT_12','DGIE','5000','RWF'],
    ['APPLICATION_FOR_COVID_19_TEST_USD','CAT_09','RBC','0','USD'],
    ['APPLICATION_FOR_COVID_19_TEST_RWF','CAT_09','RBC','0','RWF'],
    ['APPLICATION_FOR_TRANSPORT_LICENSE','CAT_17','RURA','10000','RWF'],
    ['DGIE_PENALTIES_PAYMENT','CAT_12','DGIE','0','RWF'],
    ['TRANSPORT_LICENSE_RENEWAL','CAT_17','RURA','400000','RWF'],
    ['LAND_CONDOMINIUM_REGISTRATION_PAYMENT','CAT_03','RLMUA','5000','RWF'],
    ['LAND_CONVERSION_FROM_LEASE_TO_FREE_HOLD_PAYMENT','CAT_03','RLMUA','5000','RWF'],
    ['LAND_FICHE_CADASTRALE_PAYMENT','CAT_03','RLMUA','10000','RWF'],
    ['VISA_ON_ARRIVAL','CAT_20','DGIE','0','RWF'],
    ['TRANSFER_TRANSCRIPTION_FEES','CAT_12','DGIE','18050','RWF'],
    ['LAND_NEW_DOCUMENT_PAYMENT','CAT_03','RLMUA','5000','RWF'],
    ['APPLICATION_VISA','CAT_12','DGIE','0','USD'],
    ['CEPGL_TRAVEL_DOCUMENT_NEW','CAT_12','DGIE','10000','RWF'],
    ['APPLICATION_PASSPORT','CAT_12','DGIE','0','RWF'],
    ['LOST_DAMAGE_PASSPORT','CAT_12','DGIE','0','RWF'],
    ['EPASSPORT_DIASPORA','CAT_12','DGIE','0','RWF'],
    ['CEPGL_TRAVEL_DOCUMENT_RENEWAL','CAT_12','DGIE','10000','RWF'],
    ['DEATH_RECORD_NEW','CAT_01','MINALOC','2000','RWF'],
    ['PURCHASE_FOR_AN_OFFICIAL_GAZETTE','CAT_05','MINIJUST','0','RWF'],
    ['DIVORCE_RECORD','CAT_02','MINALOC','2000','RWF'],
    ['TVET_FOREIGN_EQUIVALENCE_CERTIFICATE','CAT_10','NESA','1000','RWF'],
    ['CITIZENSHIP_APPLICATION_PAYMENTS','CAT_12','DGIE','500','RWF'],
    ['BIRTH_RECORD_NEW','CAT_01','MINALOC','2000','RWF'],
    ['MARRIAGE_DECLARATION','CAT_01','MINALOC','0','RWF'],
    ['CEPGL_TRAVEL_DOCUMENT','CAT_12','DGIE','0','USD'],
    ['MARRIAGE_RECORD_NEW','CAT_01','MINALOC','2000','RWF'],
    ['REGISTRATION_FOR_DRIVING_TEST_DEFINITIVE','CAT_06','RNP','10000','RWF'],
    ['CERTIFICATE_OF_DIVORCE','CAT_02','MINALOC','1500','RWF'],
    ['CEPGL_TRAVEL_DOCUMENT_REPLACE','CAT_12','DGIE','15000','RWF'],
    ['RDB_NOTARY_SERVICE','CAT_05','MINIJUST','0','RWF'],
    ['CITIZENSHIP_RENUNCIATION_PAYMENT','CAT_12','DGIE','150000','RWF'],
    ['APPLICATION_FOR_PROVISIONAL_DRIVING_LICENSE','CAT_06','RNP','10000','RWF'],
    ['TRAFFIC_FINES','CAT_06','RNP','0','RWF'],
    ['REGISTRATION_FOR_DRIVING_TEST_PROVISIONAL','CAT_06','RNP','5000','RWF'],
    ['DUPLICATE_OF_MOTOR_VEHICLE_INSPECTION_CERTIFICATE','CAT_06','RNP','10000','RWF'],
    ['MOTOR_VEHICLE_INSPECTION_APPOINTMENT','CAT_06','RNP','0','RWF'],
    ['APPLICATION_FOR_PERMIT_AND_VISA_TRANSFER','CAT_12','DGIE','18050','RWF'],
    ['TRANSFER_OF_LAND_TITLE_BASED_ON_EXCHANGE','CAT_03','RLMUA','35000','RWF'],
    ['REGISTRATION_FOR_DRIVING_LICENSE_TEST_SUPPLEMENTARY','CAT_06','RNP','10000','RWF'],
    ['NID_DIASPORA_WITHOUT_NPR_REVAMP','CAT_02','NIDA','500','RWF'],
    ['REGISTRATION_FOR_DRIVING_LICENSE_TEST_DEFINITIVE','CAT_06','RNP','10000','RWF'],
    ['CHILD_RECOGNITION_RECORD_CERTIFICATE','CAT_01','MINALOC','2000','RWF'],
    ['CHILD_RECOGNITION_RECORD_NEW','CAT_01','MINALOC','2000','RWF'],
    ['CRIMINAL_RECORD_CLEARANCE_CERTIFICATE','CAT_08','NPPA','1200','RWF'],
    ['APPLICATION_FOR_E_PROVISIONAL_DRIVING_LICENSE','CAT_06','RNP','10000','RWF'],
    ['ADOPTION_RECORD_NEW','CAT_01','MINALOC','2000','RWF'],
    ['TRANSFER_OF_LAND_E_TITLE_VOLUNTARY_SALE','CAT_03','RLMUA','30000','RWF'],
    ['REGISTRATION_FOR_DRIVING_LICENSE_TEST_PROVISIONAL_PAPER_BASED','CAT_06','RNP','5000','RWF'],
    ['REGISTRATION_FOR_DRIVING_LICENSE_TEST_PROVISIONAL_COMPUTER_BASED','CAT_06','RNP','5000','RWF'],
    ['FOREIGNER_TRAVEL_DOCUMENT','CAT_12','DGIE','10000','RWF'],
    ['RGB_NOTARY_SERVICE','CAT_05','MINIJUST','0','RWF'],
    ['SECTOR_NOTARY_SERVICE','CAT_05','MINIJUST','0','RWF'],
    ['DISTRICT_NOTARY_SERVICE','CAT_05','MINIJUST','0','RWF'],
    ['MINIJUST_NOTARY_SERVICE','CAT_05','MINIJUST','0','RWF'],
    ['LAND_FIRST_REGISTRATION_PAYMENT','CAT_03','RLMUA','5000','RWF'],
    ['APPLICATION_FOR_DEFINITIVE_DRIVING_LICENCE','CAT_06','RNP','50000','RWF'],
    ['REPLACEMENT_OF_NATIONAL_ID','CAT_02','NIDA','1500','RWF'],
    ['REPLACEMENT_OF_DRIVING_LICENSE','CAT_06','RNP','50000','RWF'],
    ['DUPLICATE_OF_DEFINITIVE_DRIVING_LICENSE','CAT_06','RNP','25000','RWF'],
    ['APPLICATION_FOR_FBO_LEGAL_PERSONALITY','CAT_15','RGB','100000','RWF'],
    ['DRIVING_LICENSE_CATEGORY_UPGRADE','CAT_06','RNP','10000','RWF'],
    ['DUPLICATE_OF_PROVISIONAL_DRIVING_LICENSE','CAT_06','RNP','5000','RWF'],
    ['NGO_REGISTRATION','CAT_15','RGB','50000','RWF'],
    ['RENEWAL_OF_PROVISIONAL_DRIVING_LICENSE','CAT_06','RNP','5000','RWF'],
    ['RENEWAL_OF_DEFINITIVE_DRIVING_LICENSE','CAT_06','RNP','5000','RWF'],
    ['VISIT_SCHEDULE_FOR_NATIONAL_MUSEUMS_OF_RWANDA','CAT_13','RCHA','0','RWF'],
    ['PUBLISH_IN_THE_OFFICIAL_GAZETTE','CAT_05','MINIJUST','0','RWF'],
    ['APPLICATION_FOR_NATIONAL_ID','CAT_02','NIDA','500','RWF'],
    ['APPLICATION_FOR_EQUATING_FOREIGN_QUALIFICATIONS_PHD_MASTERS_DEGREES_DIPLOMAS_AND_CERTIFICATES','CAT_10','HEC','1000','RWF'],
    ['APPLICATION_FOR_NGO_LEGAL_PERSONALITY','CAT_15','RGB','100000','RWF'],
    ['NID_DIASPORA_WITHOUT_NPR','CAT_02','NIDA','500','RWF'],
    ['PAYMENT_FOR_ID_CORRECTION','CAT_02','NIDA','0','RWF'],
    ['NEW_CRIMINAL_RECORD_CLEARANCE_CERTIFICATE','CAT_08','NPPA','1200','RWF']
]

channels = ['WEB', 'WEB', 'WEB', 'WEB', 'WEB', 'WEB', 'WEB', 'WEB', 'WEB', 'WEB', 'WEB','WEB', 'WEB','USSD','USSD', 'USSD', 'USSD', 'USSD','CCTV', 'HHT']
requester_type = ['CITIZEN', 'AGENT', 'AGENT']
processing_levels = ['LEVEL_1', 'LEVEL_1','LEVEL_1','LEVEL_1','LEVEL_1', 'LEVEL_2']
payment_state = ['EXPIRED', 'PAID','PENDING','PAID','PENDING','PAID','PENDING','PAID','PENDING','PAID','PENDING','PAID','PAID','PAID','PAID','PAID']

states_details = [
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_APPROVAL',  'APPROVED'],
    ['CLOSED_WITH_REJECTED',  'REJECTED'],
    ['CLOSED_WITH_REJECTED',  'REJECTED'],
    ['CLOSED_WITH_REJECTED',  'REJECTED'],
    ['CLOSED_WITH_REJECTED',  'REJECTED'],
    ['CLOSED_WITH_REJECTED',  'REJECTED'],
    ['CLOSED_WITH_REJECTED',  'REJECTED'],
    ['PENDING_RESUBMISSION',  'RFA'],
    ['PENDING_RESUBMISSION_OTP',  'RFA'],
    #['PENDING_RESUBMISSION_OTP_LEVEL_2',  'RFA'],
    #['PENDING_RESUBMISSION_OTP_LEVEL_3',  'RFA'],
    ['PAID', 'PAYMENT'],
    ['PAYMENT_FREE',  'PAYMENT'],
    ['PAYMENT_PENDING',  'PAYMENT'],
    ['SUBMITTED',  'PENDING'],
    ['RESUBMITTED',  'PENDING'],
    ['ESCALATED',  'PENDING'],
    ['DE_ESCALATED',  'PENDING'],
    #['ACKNOWLEDGED',  'PENDING'],
    ['PENDING_APPROVAL',  'PENDING'],
    #['PENDING_EMBASSY_APPROVAL',  'PENDING'],
    #['LAIS_NOTIFIED',  'PENDING'],
    #['PENDING_LEVEL_1_APPROVAL',  'PENDING'],
    ['PENDING_FINAL_APPROVAL',  'PENDING'] 
    #['PENDING_LEVEL_2_APPROVAL',  'PENDING'],
    #['PENDING_RIB_FINAL_APPROVAL',  'PENDING'],
    #['PENDING_APPOINTMENT',  'PENDING'],
    #['PENDING_NOTARIZATION',  'PENDING'],    
    #['PENDING_NIDA_APPROVAL',  'PENDING'],
    #['PENDING_LAND_APPROVAL',  'PENDING'],
    #['CONTRACT_NOTARIZED',  'PENDING'],    
    #['PENDING_NISS_ESCALATION',  'PENDING'],
    #['PENDING_LEVEL_3_APPROVAL',  'PENDING'],
    #['PENDING_LEVEL_4_APPROVAL',  'PENDING'],
    #['DE_ESCALATED_LEVEL_1',  'PENDING'],
    #['DE_ESCALATED_LEVEL_2',  'PENDING'],
    #['DE_ESCALATED_LEVEL_3',  'PENDING'],
    #['RESUBMITTED_LEVEL_1',  'PENDING'],
    #['RESUBMITTED_LEVEL_2',  'PENDING']
]


def gen_datetime(min_year=2021, max_year=datetime.now().year):
    # generate a datetime in format yyyy-mm-dd hh:mm:ss.000000
    today_datetime = datetime.now()
    return today_datetime - timedelta(days=random.randint(1,1100), hours=random.randint(1,23), minutes=random.randint(1,60), seconds=random.randint(1,60))
    

def generate_random_application():
    N = 8
    application_data = []
    strformat = '%Y-%m-%d %H:%M:%S'
    for i in range(100005,100200):
        creationdate = gen_datetime()
        selected_service = service_list[random.randint(0,144)]
        state_detail = states_details[random.randint(0,29)]
        selected_office = office_list[random.randint(0,460)]
        application = (
            'C' + creationdate.strftime('%Y%m%d') + str(i) + ''.join(random.choices(string.ascii_uppercase + string.digits, k=5)),  # application_number
            selected_service[3], # price  int,
            3,# processing_duration int,
            selected_service[3], # paid_amount int,
            5,# processing_sla  int,
            selected_service[0], # service_code varchar(100), 
            '', # service_name varchar(200), 
            selected_service[1],# service_category_code varchar(100), 
            '',# service_category_name varchar(200), 
            selected_service[2],# institution_code varchar(100),
            '',# institution_name varchar(200),
            channels[random.randint(0,19)],# application_channel varchar(100),
            state_detail[1],# application_state varchar(100),
            state_detail[0],# application_state_details varchar(100),
            creationdate.strftime(strformat),# application_date_created timestamp,
            (creationdate + timedelta(hours=48)).strftime(strformat),# application_date_payment timestamp,
            selected_service[4],# application_currency varchar(100),
            state_detail[1],# application_processing_phase varchar(100),
            '',# application_requester_location_sector varchar(100),
            '',# application_requester_location_district varchar(100),
            '',# application_requester_id varchar(100),
            requester_type[random.randint(0,2)],# application_requester_type varchar(100),
            selected_office[0],# application_processing_office_code varchar(100),
            selected_office[0],# application_processing_office_name varchar(200),
            '0' + str(selected_office[1]),# application_processing_location_sector_code varchar(100),
            '',# application_processing_location_sector_name varchar(200),
            '0' + selected_office[1][0:3],# application_processing_location_district_code varchar(100),
            '',# application_processing_location_district_name varchar(200),
            processing_levels[random.randint(0,5)],# application_processing_level varchar(100),
            '',# application_processing_reason varchar(200),
            '',# application_payment_account varchar(100),
            payment_state[random.randint(0,15)]# application_payment_state varchar(100),
            
        )
        
        application_data.append(application)
    return application_data    

application_data = generate_random_application()
print(application_data)
# Out:
# [('C20230409100005UYZOL', '1500', 3, '1500', 5, 'CERTIFICATE_OF_COHABITATION', '', 'CAT_01', '', 'MINALOC', '', 'WEB', 'PENDING', 'SUBMITTED', '2023-04-09 15:38:44', '2023-04-11 15:38:44', 'RWF', 'PENDING', '', '', '', 'CITIZEN', 'Ambarwa Stockholm', 'Ambarwa Stockholm', '060204', '', '0602', '', 'LEVEL_2', '', '', 'PAID'), ('C20211013100006JRIP1', '18050', 3, '18050', 5, 'APPLICATION_FOR_PERMIT_AND_VISA_TRANSFER', '', 'CAT_12', '', 'DGIE', '', 'USSD', 'REJECTED', 'CLOSED_WITH_REJECTED', '2021-10-13 08:04:13', '2021-10-15 08:04:13', 'RWF', 'REJECTED', '', '', '', 'CITIZEN', 'Cyabakamyi', 'Cyabakamyi', '020103', '', '0201', '', 'LEVEL_1', '', '', 'EXPIRED'), ('C20210817100007KAL67', '1500', 3, '1500', 5, 'CERTIFICATE_OF_COHABITATION', '', 'CAT_01', '', 'MINALOC', '', 'USSD', 'APPROVED', 'CLOSED_WITH_APPROVAL', '2021-08-17 19:53:59', '2021-08-19 19:53:59', 'RWF', 'APPROVED', '', '', '', 'AGENT', 'Ruramba', 'Ruramba', '020313', '', '0203', '', 'LEVEL_1', '', '', 'PENDING'), ('C202105221
# ...

# %%
# Insert application data in the database
query = f""" 
    INSERT INTO table_vone_application (
        application_number,
        price ,
        processing_duration,
        paid_amount,
        processing_sla,
        service_code , 
        service_name , 
        service_category_code, 
        service_category_name, 
        institution_code ,
        institution_name ,
        application_channel ,
        application_state ,
        application_state_details ,
        application_date_created ,
        application_date_payment ,
        application_currency ,
        application_processing_phase ,
        application_requester_location_sector ,
        application_requester_location_district ,
        application_requester_id ,
        application_requester_type ,
        application_processing_office_code ,
        application_processing_office_name ,
        application_processing_location_sector_code ,
        application_processing_location_sector_name ,
        application_processing_location_district_code ,
        application_processing_location_district_name ,
        application_processing_level ,
        application_processing_reason ,
        application_payment_account ,
        application_payment_state ) 
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
            # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
            # %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
            # %s, %s
    ) 
"""

print (query)
cursor = conn.cursor()
cursor.executemany(query, application_data)
conn.commit()
# Out:
#
#     INSERT INTO table_vone_application (
#         application_number,
#         price ,
#         processing_duration,
#         paid_amount,
#         processing_sla,
#         service_code ,
#         service_name ,
#         service_category_code,
#         service_category_name,
#         institution_code ,
#         institution_name ,
#         application_channel ,
#         application_state ,
#         application_state_details ,
#         application_date_created ,
#         application_date_payment ,
#         application_currency ,
#         application_processing_phase ,
#         application_requester_location_sector ,
#         application_requester_location_district ,
#         application_requester_id ,
#         application_requester_type ,
#         application_processing_office_code ,
#         application_processing_office_name ,
#         application_processing_location_sector_code ,
#         application_processing_location_sector_name ,
# ...

# %%
random.randint(0,5)
def run_query(query=''):
    conn = sqlite3.connect(DB_FILENAME)
    cursor = conn.cursor()
    cursor.execute(query)      
    data = cursor.fetchall()
    print(data)
    conn.close




query_trend = """
SELECT 
    strftime('%Y-%m-%d', date_created) AS application_date,
    COUNT(*) AS approved_applications
FROM 
    application
JOIN 
    Office ON application.office_code = Office.office_code
JOIN 
    location ON Office.location_code = location.location_code
WHERE 
    application.state = 'APPROVED'
    AND location.location_name = 'Location 1'
    AND date_created >= date('now', '-9 days') -- last 10 days including today
    AND date_created <= date('now') -- up to today
GROUP BY 
    strftime('%Y-%m-%d', date_created)
ORDER BY 
    strftime('%Y-%m-%d', date_created) ASC;
"""

run_query(query=query_trend)
# Out:
# [('2024-04-20', 1), ('2024-04-21', 1), ('2024-04-25', 1)]

# %%
query = """
SELECT 
    strftime('%Y-%m', date_paid) AS month,
    COUNT(*) AS approved_applications
FROM 
    application
WHERE 
    amount_paid = amount AND state='APPROVED' AND office_code IN (
        SELECT 
            o.office_code
        FROM 
            Office o, location l
        WHERE 
            o.location_code=l.location_code AND l.location_name='Location 2'
    )
GROUP BY 
    month
ORDER BY 
    month;
"""

run_query(query=query)
# Out:
# [('2021-01', 27), ('2021-02', 31), ('2021-03', 30), ('2021-04', 33), ('2021-05', 40), ('2021-06', 28), ('2021-07', 27), ('2021-08', 30), ('2021-09', 31), ('2021-10', 35), ('2021-11', 26), ('2021-12', 33), ('2022-01', 32), ('2022-02', 34), ('2022-03', 39), ('2022-04', 39), ('2022-05', 30), ('2022-06', 29), ('2022-07', 35), ('2022-08', 31), ('2022-09', 37), ('2022-10', 31), ('2022-11', 31), ('2022-12', 22), ('2023-01', 33), ('2023-02', 35), ('2023-03', 34), ('2023-04', 35), ('2023-05', 28), ('2023-06', 32), ('2023-07', 26), ('2023-08', 30), ('2023-09', 26), ('2023-10', 36), ('2023-11', 37), ('2023-12', 39), ('2024-01', 39), ('2024-02', 33), ('2024-03', 29), ('2024-04', 28), ('2024-05', 37), ('2024-06', 33), ('2024-07', 33), ('2024-08', 35), ('2024-09', 34), ('2024-10', 36), ('2024-11', 26), ('2024-12', 41)]

# %%
query="""
WITH monthly_trend AS (
    SELECT strftime('%Y-%m', date_created) AS month,
           COUNT(*) AS approved_applications
    FROM application
    WHERE state = 'APPROVED'
      AND strftime('%Y-%m', date_created) >= strftime('%Y-%m', 'now', '-12 months')
      AND office_code IN (SELECT office_code FROM Office WHERE location_code = 'L1')
    GROUP BY month
)
SELECT all_months.month, COALESCE(approved_applications, 0) AS approved_applications
FROM (
    SELECT strftime('%Y-%m', 'now', '-12 months') AS month
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-11 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-10 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-9 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-8 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-7 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-6 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-5 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-4 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-3 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-2 months')
    UNION ALL
    SELECT strftime('%Y-%m', 'now', '-1 months')
) AS all_months
LEFT JOIN monthly_trend ON all_months.month = monthly_trend.month;


"""

run_query(query=query)
# Out:
# [('2023-04', 34), ('2023-05', 33), ('2023-06', 32), ('2023-07', 34), ('2023-08', 32), ('2023-09', 35), ('2023-10', 37), ('2023-11', 31), ('2023-12', 32), ('2024-01', 36), ('2024-02', 28), ('2024-03', 22)]

# %%
query =""" 
SELECT 
    strftime('%Y-%m', date_processed) AS month, 
    COUNT(*) as approved_applications
FROM application
WHERE state = 'APPROVED' AND office_code IN (
    SELECT office_code FROM Office WHERE location_code in ('L1','L2','L3','L4','L5')
) AND date_processed >= DATE('now', '-12 months')
GROUP BY strftime('%Y-%m', date_processed)
ORDER BY month;
"""

run_query(query=query)
# Out:
# [('2023-04', 25), ('2023-05', 170), ('2023-06', 157), ('2023-07', 153), ('2023-08', 160), ('2023-09', 158), ('2023-10', 165), ('2023-11', 159), ('2023-12', 175), ('2024-01', 186), ('2024-02', 158), ('2024-03', 148), ('2024-04', 148), ('2024-05', 154), ('2024-06', 166), ('2024-07', 158), ('2024-08', 166), ('2024-09', 156), ('2024-10', 164), ('2024-11', 149), ('2024-12', 170)]
